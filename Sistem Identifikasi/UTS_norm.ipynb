# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from scipy import signal

# %%
# Set a random seed for reproducibility
np.random.seed(42)

# Define the number of samples
k_max = 10000
t = np.linspace(0, k_max, k_max)  # Time variable

# Generate random inputs
u = 2 * np.random.uniform(-5, 5, k_max)

# Initialize y(k) array
y = np.zeros(k_max)

# Define y(k) calculations
for k in range(1, k_max):
    y[k] = 1 / (1 + (y[k-1])**2) + 0.25 * u[k] - 0.3 * u[k-1]

# Shift arrays for y(k-1), y(k-2), u(k-1), u(k-2)
y_k_1 = np.zeros(k_max)
y_k_2 = np.zeros(k_max)
u_k_1 = np.zeros(k_max)
u_k_2 = np.zeros(k_max)

y_k_1[1:] = y[:-1]
y_k_2[2:] = y[:-2]
u_k_1[1:] = u[:-1]
u_k_2[2:] = u[:-2]

# Set up Seaborn style
sns.set_theme(style="whitegrid")

# Create a single figure with a 3x2 grid of subplots
fig, ax = plt.subplots(3, 2, figsize=(15, 15), sharex=True)

# Plot u(k) over time
ax[0, 0].plot(t, u, label='u(k)', color='c')
ax[0, 0].set_ylabel('u(k)')
ax[0, 0].set_title('Plot of u(k) over Time')
ax[0, 0].legend()
ax[0, 0].grid(True)

# Plot y(k) over time
ax[0, 1].plot(t, y, label='y(k)', color='b')
ax[0, 1].set_ylabel('y(k)')
ax[0, 1].set_title('Plot of y(k) over Time')
ax[0, 1].legend()
ax[0, 1].grid(True)

# Plot u(k-1) over time
ax[1, 0].plot(t, u_k_1, label='u(k-1)', color='m')
ax[1, 0].set_ylabel('u(k-1)')
ax[1, 0].set_title('Plot of u(k-1) over Time')
ax[1, 0].legend()
ax[1, 0].grid(True)

# Plot y(k-1) over time
ax[1, 1].plot(t, y_k_1, label='y(k-1)', color='r')
ax[1, 1].set_ylabel('y(k-1)')
ax[1, 1].set_title('Plot of y(k-1) over Time')
ax[1, 1].legend()
ax[1, 1].grid(True)

# Plot u(k-2) over time
ax[2, 0].plot(t, u_k_2, label='u(k-2)', color='y')
ax[2, 0].set_xlabel('Time')
ax[2, 0].set_ylabel('u(k-2)')
ax[2, 0].set_title('Plot of u(k-2) over Time')
ax[2, 0].legend()
ax[2, 0].grid(True)

# Plot y(k-2) over time
ax[2, 1].plot(t, y_k_2, label='y(k-2)', color='g')
ax[2, 1].set_ylabel('y(k-2)')
ax[2, 1].set_title('Plot of y(k-2) over Time')
ax[2, 1].legend()
ax[2, 1].grid(True)

# Show the combined plot
plt.tight_layout()
plt.show()

# %%
X = np.array([y_k_1, y_k_2, u, u_k_1, u_k_2]).T
y = y.reshape(-1, 1)
u = u.reshape(-1, 1)

scaler = MinMaxScaler(feature_range=(-1, 1))

scaler.fit(u)
u_norm = scaler.transform(u.reshape(-1, 1))
u_k_1_norm = scaler.transform(u_k_1.reshape(-1, 1))
u_k_2_norm = scaler.transform(u_k_2.reshape(-1, 1)) 

scaler.fit(y)
y_norm = scaler.transform(y.reshape(-1, 1))
y_k_1_norm = scaler.transform(y_k_1.reshape(-1, 1))
y_k_2_norm = scaler.transform(y_k_2.reshape(-1, 1))

# %%
X_norm = np.array([y_k_1_norm.flatten(), y_k_2_norm.flatten(), u_norm.flatten(), u_k_1_norm.flatten(), u_k_2_norm.flatten()]).T

# Assuming X and y are your feature matrix and target vector respectively
train_size = int(0.8 * len(X))  # 80% of the data

# First 80% of the data for training
X_train = X[:train_size]
y_train = y[:train_size]

# Last 20% of the data for validation
X_val = X[train_size:]
y_val = y[train_size:]

# For the normalized data
X_train_norm = X_norm[:train_size]
y_train_norm = y_norm[:train_size]
X_val_norm = X_norm[train_size:]
y_val_norm = y_norm[train_size:]

# %%
class MLP:
    def __init__(self, layers, activations, optimizer='adam', learning_rate=0.001, l2_lambda=0.01):
        self.layers = layers
        self.activations = activations
        self.learning_rate = learning_rate
        self.l2_lambda = l2_lambda  # Regularization parameter
        self.weights, self.biases = self.initialize_weights()
        self.optimizer = optimizer
        self.momentum_w, self.momentum_b = None, None
        self.v_w, self.v_b = None, None
        self.initialize_optimizer_parameters()
        # Arrays to store training and validation loss/accuracy
        self.training_losses = []
        self.validation_losses = []
        self.training_accuracies = []
        self.validation_accuracies = []

    def initialize_weights(self):
        weights = []
        biases = []
        for i in range(len(self.layers) - 1):
            input_dim = self.layers[i]
            output_dim = self.layers[i + 1]
            
            # Nguyen-Widrow initialization
            # Step 1: Randomly initialize weights from a uniform distribution
            w = np.random.uniform(-1, 1, (input_dim, output_dim))
            
            # Step 2: Compute the scaling factor `beta`
            beta = 0.7 * output_dim ** (1.0 / input_dim)
            
            # Step 3: Normalize the weights to have unit length for each column
            norm = np.linalg.norm(w, axis=0)
            w = beta * (w / norm)
            
            # Initialize biases to zero
            b = np.zeros((1, output_dim))
            
            weights.append(w)
            biases.append(b)
        
        return weights, biases

    def initialize_optimizer_parameters(self):
        if self.optimizer in ['adam', 'rmsprop']:
            self.momentum_w = [np.zeros_like(w) for w in self.weights]
            self.momentum_b = [np.zeros_like(b) for b in self.biases]
            self.v_w = [np.zeros_like(w) for w in self.weights]
            self.v_b = [np.zeros_like(b) for b in self.biases]

        self.beta1 = 0.9
        self.beta2 = 0.999
        self.epsilon = 1e-8

    def activation(self, x, func):
        if func == 'tanh':
            return np.tanh(x)
        elif func == 'linear':
            return x

    def activation_derivative(self, x, func):
        if func == 'tanh':
            return 1 - np.tanh(x) ** 2
        elif func == 'linear':
            return np.ones_like(x)

    def forward(self, x):
        self.z_list = []
        self.a_list = [x]

        for i in range(len(self.weights)):
            z = np.dot(x, self.weights[i]) + self.biases[i]
            x = self.activation(z, self.activations[i])
            self.z_list.append(z)
            self.a_list.append(x)
        return x

    def backward(self, y_true, y_pred):
        gradients_w = []
        gradients_b = []
        loss_derivative = 2 * (y_pred - y_true) / y_true.shape[0]

        # Output layer
        delta = loss_derivative * self.activation_derivative(self.z_list[-1], self.activations[-1])
        grad_w = np.dot(self.a_list[-2].T, delta) + self.l2_lambda * self.weights[-1]
        grad_b = np.sum(delta, axis=0, keepdims=True)

        gradients_w.insert(0, grad_w)
        gradients_b.insert(0, grad_b)

        # Hidden layers
        for i in range(len(self.layers) - 3, -1, -1):
            delta = np.dot(delta, self.weights[i + 1].T) * self.activation_derivative(self.z_list[i], self.activations[i])
            grad_w = np.dot(self.a_list[i].T, delta) + self.l2_lambda * self.weights[i]
            grad_b = np.sum(delta, axis=0, keepdims=True)
            gradients_w.insert(0, grad_w)
            gradients_b.insert(0, grad_b)

        return gradients_w, gradients_b

    def update_weights(self, gradients_w, gradients_b):
        if self.optimizer == 'gradient_descent':
            for i in range(len(self.weights)):
                self.weights[i] -= self.learning_rate * gradients_w[i]
                self.biases[i] -= self.learning_rate * gradients_b[i]
        elif self.optimizer == 'sgd':
            for i in range(len(self.weights)):
                self.weights[i] -= self.learning_rate * gradients_w[i]
                self.biases[i] -= self.learning_rate * gradients_b[i]
        elif self.optimizer == 'rmsprop':
            for i in range(len(self.weights)):
                self.momentum_w[i] = self.beta2 * self.momentum_w[i] + (1 - self.beta2) * gradients_w[i]**2
                self.momentum_b[i] = self.beta2 * self.momentum_b[i] + (1 - self.beta2) * gradients_b[i]**2

                self.weights[i] -= self.learning_rate * gradients_w[i] / (np.sqrt(self.momentum_w[i]) + self.epsilon)
                self.biases[i] -= self.learning_rate * gradients_b[i] / (np.sqrt(self.momentum_b[i]) + self.epsilon)
        elif self.optimizer == 'adam':
            for i in range(len(self.weights)):
                self.momentum_w[i] = self.beta1 * self.momentum_w[i] + (1 - self.beta1) * gradients_w[i]
                self.momentum_b[i] = self.beta1 * self.momentum_b[i] + (1 - self.beta1) * gradients_b[i]

                self.v_w[i] = self.beta2 * self.v_w[i] + (1 - self.beta2) * gradients_w[i]**2
                self.v_b[i] = self.beta2 * self.v_b[i] + (1 - self.beta2) * gradients_b[i]**2

                m_w_corrected = self.momentum_w[i] / (1 - self.beta1)
                m_b_corrected = self.momentum_b[i] / (1 - self.beta1)
                v_w_corrected = self.v_w[i] / (1 - self.beta2)
                v_b_corrected = self.v_b[i] / (1 - self.beta2)

                self.weights[i] -= self.learning_rate * m_w_corrected / (np.sqrt(v_w_corrected) + self.epsilon)
                self.biases[i] -= self.learning_rate * m_b_corrected / (np.sqrt(v_b_corrected) + self.epsilon)

    def calculate_loss(self, y_true, y_pred):
        return np.mean((y_pred - y_true) ** 2) + (self.l2_lambda / 2) * sum([np.sum(w ** 2) for w in self.weights])

    def calculate_accuracy(self, y_true, y_pred):
        ss_res = np.sum((y_true - y_pred) ** 2)
        ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
        r2_score = 1 - (ss_res / ss_tot)
        return r2_score

    def train(self, x_train, y_train, x_val=None, y_val=None, epochs=100):
        for epoch in range(epochs):
            # Training phase
            y_pred_train = self.forward(x_train)
            gradients_w, gradients_b = self.backward(y_train, y_pred_train)
            self.update_weights(gradients_w, gradients_b)

            # Calculate training loss and accuracy
            train_loss = self.calculate_loss(y_train, y_pred_train)
            train_acc = self.calculate_accuracy(y_train, y_pred_train)
            self.training_losses.append(train_loss)
            self.training_accuracies.append(train_acc)

            # Validation phase (if validation data provided)
            if x_val is not None and y_val is not None:
                y_pred_val = self.forward(x_val)
                val_loss = self.calculate_loss(y_val, y_pred_val)
                val_acc = self.calculate_accuracy(y_val, y_pred_val)
                self.validation_losses.append(val_loss)
                self.validation_accuracies.append(val_acc)

                print(f"Epoch {epoch + 1}/{epochs} - Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, "
                      f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
            else:
                print(f"Epoch {epoch + 1}/{epochs} - Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}")

    def predict(self, x):
        return self.forward(x)
    
    def get_weights(self):
        return self.weights

    def get_biases(self):
        return self.biases

    def set_weights(self, weights):
        self.weights = weights

    def set_biases(self, biases):
        self.biases = biases

# %%
nn = MLP(layers=[X.shape[-1], 12, 10, 1], activations=[ 'tanh', 'tanh', 'linear'], optimizer='adam', learning_rate=0.01, l2_lambda=0.0001)

# %%
nn.train(X_train_norm, y_train_norm, x_val=X_val_norm, y_val=y_val_norm, epochs=20000)
# Out:
# Epoch 1/20000 - Train Loss: 0.2489, Train Acc: -0.5814, Val Loss: 0.1645, Val Acc: -0.0868
# Epoch 2/20000 - Train Loss: 0.1720, Train Acc: -0.0907, Val Loss: 0.1116, Val Acc: 0.2651
# Epoch 3/20000 - Train Loss: 0.1173, Train Acc: 0.2584, Val Loss: 0.0888, Val Acc: 0.4173
# Epoch 4/20000 - Train Loss: 0.0926, Train Acc: 0.4160, Val Loss: 0.0756, Val Acc: 0.5049
# Epoch 5/20000 - Train Loss: 0.0782, Train Acc: 0.5083, Val Loss: 0.0572, Val Acc: 0.6272
# Epoch 6/20000 - Train Loss: 0.0592, Train Acc: 0.6299, Val Loss: 0.0356, Val Acc: 0.7708
# Epoch 7/20000 - Train Loss: 0.0374, Train Acc: 0.7690, Val Loss: 0.0213, Val Acc: 0.8658
# Epoch 8/20000 - Train Loss: 0.0230, Train Acc: 0.8610, Val Loss: 0.0203, Val Acc: 0.8729
# Epoch 9/20000 - Train Loss: 0.0215, Train Acc: 0.8701, Val Loss: 0.0248, Val Acc: 0.8429
# Epoch 10/20000 - Train Loss: 0.0255, Train Acc: 0.8449, Val Loss: 0.0245, Val Acc: 0.8452
# Epoch 11/20000 - Train Loss: 0.0247, Train Acc: 0.8497, Val Loss: 0.0201, Val Acc: 0.8746
# Epoch 12/20000 - Train Loss: 0.0202, Train Acc: 0.8786, Val Loss: 0.0184, Val Acc: 0.8856
# Epoch 13/20000 - Train Loss: 0.0186, Train Acc: 0.8887, Val Loss: 0.0215, Val Acc: 0.8648
# Epoch 14/20000 - Train Loss: 0.0218, Train Acc: 0.8683, Val Loss: 0.0237, Val Acc: 0.8506
# Epoch 15/20000 - Train Loss: 0.0240, Train Acc: 0.8546, Val Loss: 0.0205, Val Acc: 0.8715
# Epoch 16/20000 - Train Loss: 0.0208, Train Acc: 0.8747, Val Loss: 0.0147, Val Acc: 0.9101
# Epoch 17/20000 - Train Loss: 0.0150, Train Acc: 0.9118, Val Loss: 0.0108, Val Acc: 0.9358
# Epoch 18/20000 - Train Loss: 0.0111, Train Acc: 0.9366, Val Loss: 0.0104, Val Acc: 0.9386
# Epoch 19/20000 - Train Loss: 0.0107, Train Acc: 0.9391, Val Loss: 0.0115, Val Acc: 0.9314
# Epoch 20/20000 - Train Loss: 0.0119, Train Acc: 0.9318, Val Loss: 0.0116, Val Acc: 0.9304
# Epoch 21/20000 - Train Loss: 0.0121, Train Acc: 0.9304, Val Loss: 0.0104, Val Acc: 0.9386
# Epoch 22/20000 - Train Loss: 0.0110, Train Acc: 0.9377, Val Loss: 0.0091, Val Acc: 0.9476
# Epoch 23/20000 - Train Loss: 0.0097, Train Acc: 0.9460, Val Loss: 0.0088, Val Acc: 0.9495
# Epoch 24/20000 - Train Loss: 0.0094, Train Acc: 0.9478, Val Loss: 0.0096, Val Acc: 0.9443
# Epoch 25/20000 - Train Loss: 0.0101, Train Acc: 0.9431, Val Loss: 0.0104, Val Acc: 0.9389
# Epoch 26/20000 - Train Loss: 0.0109, Train Acc: 0.9382, Val Loss: 0.0103, Val Acc: 0.9396
# Epoch 27/20000 - Train Loss: 0.0108, Train Acc: 0.9390, Val Loss: 0.0092, Val Acc: 0.9468
# Epoch 28/20000 - Train Loss: 0.0097, Train Acc: 0.9459, Val Loss: 0.0078, Val Acc: 0.9558
# Epoch 29/20000 - Train Loss: 0.0083, Train Acc: 0.9546, Val Loss: 0.0069, Val Acc: 0.9618
# Epoch 30/20000 - Train Loss: 0.0074, Train Acc: 0.9606, Val Loss: 0.0067, Val Acc: 0.9636
# Epoch 31/20000 - Train Loss: 0.0071, Train Acc: 0.9626, Val Loss: 0.0067, Val Acc: 0.9635
# Epoch 32/20000 - Train Loss: 0.0070, Train Acc: 0.9630, Val Loss: 0.0065, Val Acc: 0.9645
# Epoch 33/20000 - Train Loss: 0.0068, Train Acc: 0.9644, Val Loss: 0.0062, Val Acc: 0.9671
# Epoch 34/20000 - Train Loss: 0.0063, Train Acc: 0.9672, Val Loss: 0.0058, Val Acc: 0.9695
# Epoch 35/20000 - Train Loss: 0.0060, Train Acc: 0.9696, Val Loss: 0.0057, Val Acc: 0.9698
# Epoch 36/20000 - Train Loss: 0.0059, Train Acc: 0.9700, Val Loss: 0.0060, Val Acc: 0.9681
# Epoch 37/20000 - Train Loss: 0.0062, Train Acc: 0.9683, Val Loss: 0.0063, Val Acc: 0.9662
# Epoch 38/20000 - Train Loss: 0.0065, Train Acc: 0.9664, Val Loss: 0.0063, Val Acc: 0.9659
# Epoch 39/20000 - Train Loss: 0.0065, Train Acc: 0.9661, Val Loss: 0.0061, Val Acc: 0.9676
# Epoch 40/20000 - Train Loss: 0.0062, Train Acc: 0.9678, Val Loss: 0.0057, Val Acc: 0.9701
# Epoch 41/20000 - Train Loss: 0.0058, Train Acc: 0.9703, Val Loss: 0.0054, Val Acc: 0.9721
# Epoch 42/20000 - Train Loss: 0.0055, Train Acc: 0.9724, Val Loss: 0.0052, Val Acc: 0.9731
# Epoch 43/20000 - Train Loss: 0.0054, Train Acc: 0.9734, Val Loss: 0.0052, Val Acc: 0.9735
# Epoch 44/20000 - Train Loss: 0.0053, Train Acc: 0.9738, Val Loss: 0.0051, Val Acc: 0.9742
# Epoch 45/20000 - Train Loss: 0.0052, Train Acc: 0.9743, Val Loss: 0.0049, Val Acc: 0.9752
# Epoch 46/20000 - Train Loss: 0.0051, Train Acc: 0.9753, Val Loss: 0.0048, Val Acc: 0.9762
# Epoch 47/20000 - Train Loss: 0.0049, Train Acc: 0.9762, Val Loss: 0.0047, Val Acc: 0.9767
# Epoch 48/20000 - Train Loss: 0.0049, Train Acc: 0.9766, Val Loss: 0.0047, Val Acc: 0.9765
# Epoch 49/20000 - Train Loss: 0.0049, Train Acc: 0.9764, Val Loss: 0.0048, Val Acc: 0.9760
# Epoch 50/20000 - Train Loss: 0.0050, Train Acc: 0.9760, Val Loss: 0.0048, Val Acc: 0.9759
# Epoch 51/20000 - Train Loss: 0.0050, Train Acc: 0.9758, Val Loss: 0.0048, Val Acc: 0.9763
# Epoch 52/20000 - Train Loss: 0.0049, Train Acc: 0.9763, Val Loss: 0.0046, Val Acc: 0.9771
# Epoch 53/20000 - Train Loss: 0.0048, Train Acc: 0.9771, Val Loss: 0.0045, Val Acc: 0.9779
# Epoch 54/20000 - Train Loss: 0.0047, Train Acc: 0.9779, Val Loss: 0.0045, Val Acc: 0.9783
# Epoch 55/20000 - Train Loss: 0.0046, Train Acc: 0.9784, Val Loss: 0.0044, Val Acc: 0.9785
# Epoch 56/20000 - Train Loss: 0.0045, Train Acc: 0.9787, Val Loss: 0.0044, Val Acc: 0.9788
# Epoch 57/20000 - Train Loss: 0.0045, Train Acc: 0.9790, Val Loss: 0.0043, Val Acc: 0.9792
# Epoch 58/20000 - Train Loss: 0.0044, Train Acc: 0.9795, Val Loss: 0.0043, Val Acc: 0.9796
# Epoch 59/20000 - Train Loss: 0.0043, Train Acc: 0.9799, Val Loss: 0.0042, Val Acc: 0.9798
# Epoch 60/20000 - Train Loss: 0.0043, Train Acc: 0.9802, Val Loss: 0.0042, Val Acc: 0.9799
# Epoch 61/20000 - Train Loss: 0.0043, Train Acc: 0.9802, Val Loss: 0.0042, Val Acc: 0.9798
# Epoch 62/20000 - Train Loss: 0.0043, Train Acc: 0.9802, Val Loss: 0.0042, Val Acc: 0.9798
# Epoch 63/20000 - Train Loss: 0.0043, Train Acc: 0.9803, Val Loss: 0.0042, Val Acc: 0.9800
# Epoch 64/20000 - Train Loss: 0.0042, Train Acc: 0.9805, Val Loss: 0.0041, Val Acc: 0.9804
# Epoch 65/20000 - Train Loss: 0.0042, Train Acc: 0.9808, Val Loss: 0.0041, Val Acc: 0.9807
# Epoch 66/20000 - Train Loss: 0.0041, Train Acc: 0.9812, Val Loss: 0.0041, Val Acc: 0.9809
# Epoch 67/20000 - Train Loss: 0.0041, Train Acc: 0.9814, Val Loss: 0.0040, Val Acc: 0.9811
# Epoch 68/20000 - Train Loss: 0.0041, Train Acc: 0.9816, Val Loss: 0.0040, Val Acc: 0.9813
# Epoch 69/20000 - Train Loss: 0.0040, Train Acc: 0.9818, Val Loss: 0.0040, Val Acc: 0.9815
# Epoch 70/20000 - Train Loss: 0.0040, Train Acc: 0.9820, Val Loss: 0.0039, Val Acc: 0.9818
# Epoch 71/20000 - Train Loss: 0.0040, Train Acc: 0.9822, Val Loss: 0.0039, Val Acc: 0.9819
# Epoch 72/20000 - Train Loss: 0.0039, Train Acc: 0.9824, Val Loss: 0.0039, Val Acc: 0.9820
# Epoch 73/20000 - Train Loss: 0.0039, Train Acc: 0.9825, Val Loss: 0.0039, Val Acc: 0.9821
# Epoch 74/20000 - Train Loss: 0.0039, Train Acc: 0.9825, Val Loss: 0.0039, Val Acc: 0.9822
# Epoch 75/20000 - Train Loss: 0.0039, Train Acc: 0.9826, Val Loss: 0.0038, Val Acc: 0.9823
# Epoch 76/20000 - Train Loss: 0.0039, Train Acc: 0.9828, Val Loss: 0.0038, Val Acc: 0.9825
# Epoch 77/20000 - Train Loss: 0.0039, Train Acc: 0.9830, Val Loss: 0.0038, Val Acc: 0.9826
# Epoch 78/20000 - Train Loss: 0.0038, Train Acc: 0.9831, Val Loss: 0.0038, Val Acc: 0.9827
# Epoch 79/20000 - Train Loss: 0.0038, Train Acc: 0.9833, Val Loss: 0.0038, Val Acc: 0.9828
# Epoch 80/20000 - Train Loss: 0.0038, Train Acc: 0.9834, Val Loss: 0.0038, Val Acc: 0.9829
# Epoch 81/20000 - Train Loss: 0.0038, Train Acc: 0.9835, Val Loss: 0.0037, Val Acc: 0.9830
# Epoch 82/20000 - Train Loss: 0.0037, Train Acc: 0.9836, Val Loss: 0.0037, Val Acc: 0.9832
# Epoch 83/20000 - Train Loss: 0.0037, Train Acc: 0.9838, Val Loss: 0.0037, Val Acc: 0.9833
# Epoch 84/20000 - Train Loss: 0.0037, Train Acc: 0.9839, Val Loss: 0.0037, Val Acc: 0.9833
# Epoch 85/20000 - Train Loss: 0.0037, Train Acc: 0.9840, Val Loss: 0.0037, Val Acc: 0.9834
# Epoch 86/20000 - Train Loss: 0.0037, Train Acc: 0.9840, Val Loss: 0.0037, Val Acc: 0.9835
# Epoch 87/20000 - Train Loss: 0.0037, Train Acc: 0.9841, Val Loss: 0.0036, Val Acc: 0.9836
# Epoch 88/20000 - Train Loss: 0.0036, Train Acc: 0.9842, Val Loss: 0.0036, Val Acc: 0.9837
# Epoch 89/20000 - Train Loss: 0.0036, Train Acc: 0.9844, Val Loss: 0.0036, Val Acc: 0.9838
# Epoch 90/20000 - Train Loss: 0.0036, Train Acc: 0.9844, Val Loss: 0.0036, Val Acc: 0.9839
# Epoch 91/20000 - Train Loss: 0.0036, Train Acc: 0.9845, Val Loss: 0.0036, Val Acc: 0.9840
# Epoch 92/20000 - Train Loss: 0.0036, Train Acc: 0.9846, Val Loss: 0.0036, Val Acc: 0.9841
# Epoch 93/20000 - Train Loss: 0.0036, Train Acc: 0.9847, Val Loss: 0.0036, Val Acc: 0.9842
# Epoch 94/20000 - Train Loss: 0.0036, Train Acc: 0.9848, Val Loss: 0.0035, Val Acc: 0.9842
# Epoch 95/20000 - Train Loss: 0.0035, Train Acc: 0.9849, Val Loss: 0.0035, Val Acc: 0.9843
# Epoch 96/20000 - Train Loss: 0.0035, Train Acc: 0.9850, Val Loss: 0.0035, Val Acc: 0.9844
# Epoch 97/20000 - Train Loss: 0.0035, Train Acc: 0.9850, Val Loss: 0.0035, Val Acc: 0.9845
# Epoch 98/20000 - Train Loss: 0.0035, Train Acc: 0.9851, Val Loss: 0.0035, Val Acc: 0.9845
# Epoch 99/20000 - Train Loss: 0.0035, Train Acc: 0.9852, Val Loss: 0.0035, Val Acc: 0.9846
# Epoch 100/20000 - Train Loss: 0.0035, Train Acc: 0.9853, Val Loss: 0.0035, Val Acc: 0.9847
# Epoch 101/20000 - Train Loss: 0.0035, Train Acc: 0.9853, Val Loss: 0.0035, Val Acc: 0.9847
# Epoch 102/20000 - Train Loss: 0.0035, Train Acc: 0.9854, Val Loss: 0.0035, Val Acc: 0.9848
# Epoch 103/20000 - Train Loss: 0.0034, Train Acc: 0.9855, Val Loss: 0.0034, Val Acc: 0.9849
# Epoch 104/20000 - Train Loss: 0.0034, Train Acc: 0.9855, Val Loss: 0.0034, Val Acc: 0.9849
# Epoch 105/20000 - Train Loss: 0.0034, Train Acc: 0.9856, Val Loss: 0.0034, Val Acc: 0.9850
# Epoch 106/20000 - Train Loss: 0.0034, Train Acc: 0.9857, Val Loss: 0.0034, Val Acc: 0.9851
# Epoch 107/20000 - Train Loss: 0.0034, Train Acc: 0.9857, Val Loss: 0.0034, Val Acc: 0.9851
# Epoch 108/20000 - Train Loss: 0.0034, Train Acc: 0.9858, Val Loss: 0.0034, Val Acc: 0.9852
# Epoch 109/20000 - Train Loss: 0.0034, Train Acc: 0.9859, Val Loss: 0.0034, Val Acc: 0.9853
# Epoch 110/20000 - Train Loss: 0.0034, Train Acc: 0.9859, Val Loss: 0.0034, Val Acc: 0.9853
# Epoch 111/20000 - Train Loss: 0.0034, Train Acc: 0.9860, Val Loss: 0.0034, Val Acc: 0.9854
# Epoch 112/20000 - Train Loss: 0.0034, Train Acc: 0.9861, Val Loss: 0.0034, Val Acc: 0.9854
# Epoch 113/20000 - Train Loss: 0.0033, Train Acc: 0.9861, Val Loss: 0.0033, Val Acc: 0.9855
# Epoch 114/20000 - Train Loss: 0.0033, Train Acc: 0.9862, Val Loss: 0.0033, Val Acc: 0.9855
# Epoch 115/20000 - Train Loss: 0.0033, Train Acc: 0.9862, Val Loss: 0.0033, Val Acc: 0.9856
# Epoch 116/20000 - Train Loss: 0.0033, Train Acc: 0.9863, Val Loss: 0.0033, Val Acc: 0.9857
# Epoch 117/20000 - Train Loss: 0.0033, Train Acc: 0.9864, Val Loss: 0.0033, Val Acc: 0.9857
# Epoch 118/20000 - Train Loss: 0.0033, Train Acc: 0.9864, Val Loss: 0.0033, Val Acc: 0.9858
# Epoch 119/20000 - Train Loss: 0.0033, Train Acc: 0.9865, Val Loss: 0.0033, Val Acc: 0.9858
# Epoch 120/20000 - Train Loss: 0.0033, Train Acc: 0.9865, Val Loss: 0.0033, Val Acc: 0.9859
# Epoch 121/20000 - Train Loss: 0.0033, Train Acc: 0.9866, Val Loss: 0.0033, Val Acc: 0.9859
# Epoch 122/20000 - Train Loss: 0.0033, Train Acc: 0.9866, Val Loss: 0.0033, Val Acc: 0.9860
# Epoch 123/20000 - Train Loss: 0.0032, Train Acc: 0.9867, Val Loss: 0.0033, Val Acc: 0.9860
# Epoch 124/20000 - Train Loss: 0.0032, Train Acc: 0.9867, Val Loss: 0.0033, Val Acc: 0.9861
# Epoch 125/20000 - Train Loss: 0.0032, Train Acc: 0.9868, Val Loss: 0.0032, Val Acc: 0.9861
# Epoch 126/20000 - Train Loss: 0.0032, Train Acc: 0.9868, Val Loss: 0.0032, Val Acc: 0.9862
# Epoch 127/20000 - Train Loss: 0.0032, Train Acc: 0.9869, Val Loss: 0.0032, Val Acc: 0.9862
# Epoch 128/20000 - Train Loss: 0.0032, Train Acc: 0.9869, Val Loss: 0.0032, Val Acc: 0.9863
# Epoch 129/20000 - Train Loss: 0.0032, Train Acc: 0.9870, Val Loss: 0.0032, Val Acc: 0.9863
# Epoch 130/20000 - Train Loss: 0.0032, Train Acc: 0.9870, Val Loss: 0.0032, Val Acc: 0.9864
# Epoch 131/20000 - Train Loss: 0.0032, Train Acc: 0.9871, Val Loss: 0.0032, Val Acc: 0.9864
# Epoch 132/20000 - Train Loss: 0.0032, Train Acc: 0.9871, Val Loss: 0.0032, Val Acc: 0.9865
# Epoch 133/20000 - Train Loss: 0.0032, Train Acc: 0.9872, Val Loss: 0.0032, Val Acc: 0.9865
# Epoch 134/20000 - Train Loss: 0.0032, Train Acc: 0.9872, Val Loss: 0.0032, Val Acc: 0.9866
# Epoch 135/20000 - Train Loss: 0.0031, Train Acc: 0.9873, Val Loss: 0.0032, Val Acc: 0.9866
# Epoch 136/20000 - Train Loss: 0.0031, Train Acc: 0.9873, Val Loss: 0.0032, Val Acc: 0.9867
# Epoch 137/20000 - Train Loss: 0.0031, Train Acc: 0.9874, Val Loss: 0.0031, Val Acc: 0.9867
# Epoch 138/20000 - Train Loss: 0.0031, Train Acc: 0.9874, Val Loss: 0.0031, Val Acc: 0.9867
# Epoch 139/20000 - Train Loss: 0.0031, Train Acc: 0.9874, Val Loss: 0.0031, Val Acc: 0.9868
# Epoch 140/20000 - Train Loss: 0.0031, Train Acc: 0.9875, Val Loss: 0.0031, Val Acc: 0.9868
# Epoch 141/20000 - Train Loss: 0.0031, Train Acc: 0.9875, Val Loss: 0.0031, Val Acc: 0.9869
# Epoch 142/20000 - Train Loss: 0.0031, Train Acc: 0.9876, Val Loss: 0.0031, Val Acc: 0.9869
# Epoch 143/20000 - Train Loss: 0.0031, Train Acc: 0.9876, Val Loss: 0.0031, Val Acc: 0.9870
# Epoch 144/20000 - Train Loss: 0.0031, Train Acc: 0.9877, Val Loss: 0.0031, Val Acc: 0.9870
# Epoch 145/20000 - Train Loss: 0.0031, Train Acc: 0.9877, Val Loss: 0.0031, Val Acc: 0.9870
# Epoch 146/20000 - Train Loss: 0.0031, Train Acc: 0.9877, Val Loss: 0.0031, Val Acc: 0.9871
# Epoch 147/20000 - Train Loss: 0.0031, Train Acc: 0.9878, Val Loss: 0.0031, Val Acc: 0.9871
# Epoch 148/20000 - Train Loss: 0.0031, Train Acc: 0.9878, Val Loss: 0.0031, Val Acc: 0.9872
# Epoch 149/20000 - Train Loss: 0.0030, Train Acc: 0.9879, Val Loss: 0.0031, Val Acc: 0.9872
# Epoch 150/20000 - Train Loss: 0.0030, Train Acc: 0.9879, Val Loss: 0.0031, Val Acc: 0.9873
# Epoch 151/20000 - Train Loss: 0.0030, Train Acc: 0.9879, Val Loss: 0.0031, Val Acc: 0.9873
# Epoch 152/20000 - Train Loss: 0.0030, Train Acc: 0.9880, Val Loss: 0.0030, Val Acc: 0.9873
# Epoch 153/20000 - Train Loss: 0.0030, Train Acc: 0.9880, Val Loss: 0.0030, Val Acc: 0.9874
# Epoch 154/20000 - Train Loss: 0.0030, Train Acc: 0.9881, Val Loss: 0.0030, Val Acc: 0.9874
# Epoch 155/20000 - Train Loss: 0.0030, Train Acc: 0.9881, Val Loss: 0.0030, Val Acc: 0.9874
# Epoch 156/20000 - Train Loss: 0.0030, Train Acc: 0.9881, Val Loss: 0.0030, Val Acc: 0.9875
# Epoch 157/20000 - Train Loss: 0.0030, Train Acc: 0.9882, Val Loss: 0.0030, Val Acc: 0.9875
# Epoch 158/20000 - Train Loss: 0.0030, Train Acc: 0.9882, Val Loss: 0.0030, Val Acc: 0.9876
# Epoch 159/20000 - Train Loss: 0.0030, Train Acc: 0.9882, Val Loss: 0.0030, Val Acc: 0.9876
# Epoch 160/20000 - Train Loss: 0.0030, Train Acc: 0.9883, Val Loss: 0.0030, Val Acc: 0.9876
# Epoch 161/20000 - Train Loss: 0.0030, Train Acc: 0.9883, Val Loss: 0.0030, Val Acc: 0.9877
# Epoch 162/20000 - Train Loss: 0.0030, Train Acc: 0.9884, Val Loss: 0.0030, Val Acc: 0.9877
# Epoch 163/20000 - Train Loss: 0.0030, Train Acc: 0.9884, Val Loss: 0.0030, Val Acc: 0.9877
# Epoch 164/20000 - Train Loss: 0.0029, Train Acc: 0.9884, Val Loss: 0.0030, Val Acc: 0.9878
# Epoch 165/20000 - Train Loss: 0.0029, Train Acc: 0.9885, Val Loss: 0.0030, Val Acc: 0.9878
# Epoch 166/20000 - Train Loss: 0.0029, Train Acc: 0.9885, Val Loss: 0.0030, Val Acc: 0.9879
# Epoch 167/20000 - Train Loss: 0.0029, Train Acc: 0.9885, Val Loss: 0.0030, Val Acc: 0.9879
# Epoch 168/20000 - Train Loss: 0.0029, Train Acc: 0.9886, Val Loss: 0.0029, Val Acc: 0.9879
# Epoch 169/20000 - Train Loss: 0.0029, Train Acc: 0.9886, Val Loss: 0.0029, Val Acc: 0.9880
# Epoch 170/20000 - Train Loss: 0.0029, Train Acc: 0.9886, Val Loss: 0.0029, Val Acc: 0.9880
# Epoch 171/20000 - Train Loss: 0.0029, Train Acc: 0.9887, Val Loss: 0.0029, Val Acc: 0.9880
# Epoch 172/20000 - Train Loss: 0.0029, Train Acc: 0.9887, Val Loss: 0.0029, Val Acc: 0.9881
# Epoch 173/20000 - Train Loss: 0.0029, Train Acc: 0.9887, Val Loss: 0.0029, Val Acc: 0.9881
# Epoch 174/20000 - Train Loss: 0.0029, Train Acc: 0.9888, Val Loss: 0.0029, Val Acc: 0.9881
# Epoch 175/20000 - Train Loss: 0.0029, Train Acc: 0.9888, Val Loss: 0.0029, Val Acc: 0.9882
# Epoch 176/20000 - Train Loss: 0.0029, Train Acc: 0.9888, Val Loss: 0.0029, Val Acc: 0.9882
# Epoch 177/20000 - Train Loss: 0.0029, Train Acc: 0.9889, Val Loss: 0.0029, Val Acc: 0.9882
# Epoch 178/20000 - Train Loss: 0.0029, Train Acc: 0.9889, Val Loss: 0.0029, Val Acc: 0.9883
# Epoch 179/20000 - Train Loss: 0.0029, Train Acc: 0.9889, Val Loss: 0.0029, Val Acc: 0.9883
# Epoch 180/20000 - Train Loss: 0.0029, Train Acc: 0.9890, Val Loss: 0.0029, Val Acc: 0.9883
# Epoch 181/20000 - Train Loss: 0.0028, Train Acc: 0.9890, Val Loss: 0.0029, Val Acc: 0.9884
# Epoch 182/20000 - Train Loss: 0.0028, Train Acc: 0.9890, Val Loss: 0.0029, Val Acc: 0.9884
# Epoch 183/20000 - Train Loss: 0.0028, Train Acc: 0.9891, Val Loss: 0.0029, Val Acc: 0.9884
# Epoch 184/20000 - Train Loss: 0.0028, Train Acc: 0.9891, Val Loss: 0.0029, Val Acc: 0.9885
# Epoch 185/20000 - Train Loss: 0.0028, Train Acc: 0.9891, Val Loss: 0.0029, Val Acc: 0.9885
# Epoch 186/20000 - Train Loss: 0.0028, Train Acc: 0.9892, Val Loss: 0.0028, Val Acc: 0.9885
# Epoch 187/20000 - Train Loss: 0.0028, Train Acc: 0.9892, Val Loss: 0.0028, Val Acc: 0.9885
# Epoch 188/20000 - Train Loss: 0.0028, Train Acc: 0.9892, Val Loss: 0.0028, Val Acc: 0.9886
# Epoch 189/20000 - Train Loss: 0.0028, Train Acc: 0.9893, Val Loss: 0.0028, Val Acc: 0.9886
# Epoch 190/20000 - Train Loss: 0.0028, Train Acc: 0.9893, Val Loss: 0.0028, Val Acc: 0.9886
# Epoch 191/20000 - Train Loss: 0.0028, Train Acc: 0.9893, Val Loss: 0.0028, Val Acc: 0.9887
# Epoch 192/20000 - Train Loss: 0.0028, Train Acc: 0.9893, Val Loss: 0.0028, Val Acc: 0.9887
# Epoch 193/20000 - Train Loss: 0.0028, Train Acc: 0.9894, Val Loss: 0.0028, Val Acc: 0.9887
# Epoch 194/20000 - Train Loss: 0.0028, Train Acc: 0.9894, Val Loss: 0.0028, Val Acc: 0.9888
# Epoch 195/20000 - Train Loss: 0.0028, Train Acc: 0.9894, Val Loss: 0.0028, Val Acc: 0.9888
# Epoch 196/20000 - Train Loss: 0.0028, Train Acc: 0.9895, Val Loss: 0.0028, Val Acc: 0.9888
# Epoch 197/20000 - Train Loss: 0.0028, Train Acc: 0.9895, Val Loss: 0.0028, Val Acc: 0.9889
# Epoch 198/20000 - Train Loss: 0.0028, Train Acc: 0.9895, Val Loss: 0.0028, Val Acc: 0.9889
# Epoch 199/20000 - Train Loss: 0.0028, Train Acc: 0.9895, Val Loss: 0.0028, Val Acc: 0.9889
# Epoch 200/20000 - Train Loss: 0.0027, Train Acc: 0.9896, Val Loss: 0.0028, Val Acc: 0.9889
# Epoch 201/20000 - Train Loss: 0.0027, Train Acc: 0.9896, Val Loss: 0.0028, Val Acc: 0.9890
# Epoch 202/20000 - Train Loss: 0.0027, Train Acc: 0.9896, Val Loss: 0.0028, Val Acc: 0.9890
# Epoch 203/20000 - Train Loss: 0.0027, Train Acc: 0.9897, Val Loss: 0.0028, Val Acc: 0.9890
# Epoch 204/20000 - Train Loss: 0.0027, Train Acc: 0.9897, Val Loss: 0.0028, Val Acc: 0.9891
# Epoch 205/20000 - Train Loss: 0.0027, Train Acc: 0.9897, Val Loss: 0.0028, Val Acc: 0.9891
# Epoch 206/20000 - Train Loss: 0.0027, Train Acc: 0.9897, Val Loss: 0.0027, Val Acc: 0.9891
# Epoch 207/20000 - Train Loss: 0.0027, Train Acc: 0.9898, Val Loss: 0.0027, Val Acc: 0.9891
# Epoch 208/20000 - Train Loss: 0.0027, Train Acc: 0.9898, Val Loss: 0.0027, Val Acc: 0.9892
# Epoch 209/20000 - Train Loss: 0.0027, Train Acc: 0.9898, Val Loss: 0.0027, Val Acc: 0.9892
# Epoch 210/20000 - Train Loss: 0.0027, Train Acc: 0.9899, Val Loss: 0.0027, Val Acc: 0.9892
# Epoch 211/20000 - Train Loss: 0.0027, Train Acc: 0.9899, Val Loss: 0.0027, Val Acc: 0.9893
# Epoch 212/20000 - Train Loss: 0.0027, Train Acc: 0.9899, Val Loss: 0.0027, Val Acc: 0.9893
# Epoch 213/20000 - Train Loss: 0.0027, Train Acc: 0.9899, Val Loss: 0.0027, Val Acc: 0.9893
# Epoch 214/20000 - Train Loss: 0.0027, Train Acc: 0.9900, Val Loss: 0.0027, Val Acc: 0.9893
# Epoch 215/20000 - Train Loss: 0.0027, Train Acc: 0.9900, Val Loss: 0.0027, Val Acc: 0.9894
# Epoch 216/20000 - Train Loss: 0.0027, Train Acc: 0.9900, Val Loss: 0.0027, Val Acc: 0.9894
# Epoch 217/20000 - Train Loss: 0.0027, Train Acc: 0.9901, Val Loss: 0.0027, Val Acc: 0.9894
# Epoch 218/20000 - Train Loss: 0.0027, Train Acc: 0.9901, Val Loss: 0.0027, Val Acc: 0.9895
# Epoch 219/20000 - Train Loss: 0.0027, Train Acc: 0.9901, Val Loss: 0.0027, Val Acc: 0.9895
# Epoch 220/20000 - Train Loss: 0.0027, Train Acc: 0.9901, Val Loss: 0.0027, Val Acc: 0.9895
# Epoch 221/20000 - Train Loss: 0.0026, Train Acc: 0.9902, Val Loss: 0.0027, Val Acc: 0.9895
# Epoch 222/20000 - Train Loss: 0.0026, Train Acc: 0.9902, Val Loss: 0.0027, Val Acc: 0.9896
# Epoch 223/20000 - Train Loss: 0.0026, Train Acc: 0.9902, Val Loss: 0.0027, Val Acc: 0.9896
# Epoch 224/20000 - Train Loss: 0.0026, Train Acc: 0.9902, Val Loss: 0.0027, Val Acc: 0.9896
# Epoch 225/20000 - Train Loss: 0.0026, Train Acc: 0.9903, Val Loss: 0.0027, Val Acc: 0.9896
# Epoch 226/20000 - Train Loss: 0.0026, Train Acc: 0.9903, Val Loss: 0.0027, Val Acc: 0.9897
# Epoch 227/20000 - Train Loss: 0.0026, Train Acc: 0.9903, Val Loss: 0.0027, Val Acc: 0.9897
# Epoch 228/20000 - Train Loss: 0.0026, Train Acc: 0.9903, Val Loss: 0.0026, Val Acc: 0.9897
# Epoch 229/20000 - Train Loss: 0.0026, Train Acc: 0.9904, Val Loss: 0.0026, Val Acc: 0.9897
# Epoch 230/20000 - Train Loss: 0.0026, Train Acc: 0.9904, Val Loss: 0.0026, Val Acc: 0.9898
# Epoch 231/20000 - Train Loss: 0.0026, Train Acc: 0.9904, Val Loss: 0.0026, Val Acc: 0.9898
# Epoch 232/20000 - Train Loss: 0.0026, Train Acc: 0.9904, Val Loss: 0.0026, Val Acc: 0.9898
# Epoch 233/20000 - Train Loss: 0.0026, Train Acc: 0.9905, Val Loss: 0.0026, Val Acc: 0.9899
# Epoch 234/20000 - Train Loss: 0.0026, Train Acc: 0.9905, Val Loss: 0.0026, Val Acc: 0.9899
# Epoch 235/20000 - Train Loss: 0.0026, Train Acc: 0.9905, Val Loss: 0.0026, Val Acc: 0.9899
# Epoch 236/20000 - Train Loss: 0.0026, Train Acc: 0.9905, Val Loss: 0.0026, Val Acc: 0.9899
# Epoch 237/20000 - Train Loss: 0.0026, Train Acc: 0.9906, Val Loss: 0.0026, Val Acc: 0.9900
# Epoch 238/20000 - Train Loss: 0.0026, Train Acc: 0.9906, Val Loss: 0.0026, Val Acc: 0.9900
# Epoch 239/20000 - Train Loss: 0.0026, Train Acc: 0.9906, Val Loss: 0.0026, Val Acc: 0.9900
# Epoch 240/20000 - Train Loss: 0.0026, Train Acc: 0.9906, Val Loss: 0.0026, Val Acc: 0.9900
# Epoch 241/20000 - Train Loss: 0.0026, Train Acc: 0.9907, Val Loss: 0.0026, Val Acc: 0.9901
# Epoch 242/20000 - Train Loss: 0.0026, Train Acc: 0.9907, Val Loss: 0.0026, Val Acc: 0.9901
# Epoch 243/20000 - Train Loss: 0.0026, Train Acc: 0.9907, Val Loss: 0.0026, Val Acc: 0.9901
# Epoch 244/20000 - Train Loss: 0.0025, Train Acc: 0.9907, Val Loss: 0.0026, Val Acc: 0.9901
# Epoch 245/20000 - Train Loss: 0.0025, Train Acc: 0.9908, Val Loss: 0.0026, Val Acc: 0.9902
# Epoch 246/20000 - Train Loss: 0.0025, Train Acc: 0.9908, Val Loss: 0.0026, Val Acc: 0.9902
# Epoch 247/20000 - Train Loss: 0.0025, Train Acc: 0.9908, Val Loss: 0.0026, Val Acc: 0.9902
# Epoch 248/20000 - Train Loss: 0.0025, Train Acc: 0.9908, Val Loss: 0.0026, Val Acc: 0.9902
# Epoch 249/20000 - Train Loss: 0.0025, Train Acc: 0.9909, Val Loss: 0.0026, Val Acc: 0.9903
# Epoch 250/20000 - Train Loss: 0.0025, Train Acc: 0.9909, Val Loss: 0.0026, Val Acc: 0.9903
# Epoch 251/20000 - Train Loss: 0.0025, Train Acc: 0.9909, Val Loss: 0.0026, Val Acc: 0.9903
# Epoch 252/20000 - Train Loss: 0.0025, Train Acc: 0.9909, Val Loss: 0.0025, Val Acc: 0.9903
# Epoch 253/20000 - Train Loss: 0.0025, Train Acc: 0.9910, Val Loss: 0.0025, Val Acc: 0.9904
# Epoch 254/20000 - Train Loss: 0.0025, Train Acc: 0.9910, Val Loss: 0.0025, Val Acc: 0.9904
# Epoch 255/20000 - Train Loss: 0.0025, Train Acc: 0.9910, Val Loss: 0.0025, Val Acc: 0.9904
# Epoch 256/20000 - Train Loss: 0.0025, Train Acc: 0.9910, Val Loss: 0.0025, Val Acc: 0.9904
# Epoch 257/20000 - Train Loss: 0.0025, Train Acc: 0.9911, Val Loss: 0.0025, Val Acc: 0.9904
# Epoch 258/20000 - Train Loss: 0.0025, Train Acc: 0.9911, Val Loss: 0.0025, Val Acc: 0.9905
# Epoch 259/20000 - Train Loss: 0.0025, Train Acc: 0.9911, Val Loss: 0.0025, Val Acc: 0.9905
# Epoch 260/20000 - Train Loss: 0.0025, Train Acc: 0.9911, Val Loss: 0.0025, Val Acc: 0.9905
# Epoch 261/20000 - Train Loss: 0.0025, Train Acc: 0.9911, Val Loss: 0.0025, Val Acc: 0.9905
# Epoch 262/20000 - Train Loss: 0.0025, Train Acc: 0.9912, Val Loss: 0.0025, Val Acc: 0.9906
# Epoch 263/20000 - Train Loss: 0.0025, Train Acc: 0.9912, Val Loss: 0.0025, Val Acc: 0.9906
# Epoch 264/20000 - Train Loss: 0.0025, Train Acc: 0.9912, Val Loss: 0.0025, Val Acc: 0.9906
# Epoch 265/20000 - Train Loss: 0.0025, Train Acc: 0.9912, Val Loss: 0.0025, Val Acc: 0.9906
# Epoch 266/20000 - Train Loss: 0.0025, Train Acc: 0.9913, Val Loss: 0.0025, Val Acc: 0.9907
# Epoch 267/20000 - Train Loss: 0.0025, Train Acc: 0.9913, Val Loss: 0.0025, Val Acc: 0.9907
# Epoch 268/20000 - Train Loss: 0.0024, Train Acc: 0.9913, Val Loss: 0.0025, Val Acc: 0.9907
# Epoch 269/20000 - Train Loss: 0.0024, Train Acc: 0.9913, Val Loss: 0.0025, Val Acc: 0.9907
# Epoch 270/20000 - Train Loss: 0.0024, Train Acc: 0.9913, Val Loss: 0.0025, Val Acc: 0.9908
# Epoch 271/20000 - Train Loss: 0.0024, Train Acc: 0.9914, Val Loss: 0.0025, Val Acc: 0.9908
# Epoch 272/20000 - Train Loss: 0.0024, Train Acc: 0.9914, Val Loss: 0.0025, Val Acc: 0.9908
# Epoch 273/20000 - Train Loss: 0.0024, Train Acc: 0.9914, Val Loss: 0.0025, Val Acc: 0.9908
# Epoch 274/20000 - Train Loss: 0.0024, Train Acc: 0.9914, Val Loss: 0.0025, Val Acc: 0.9908
# Epoch 275/20000 - Train Loss: 0.0024, Train Acc: 0.9915, Val Loss: 0.0025, Val Acc: 0.9909
# Epoch 276/20000 - Train Loss: 0.0024, Train Acc: 0.9915, Val Loss: 0.0025, Val Acc: 0.9909
# Epoch 277/20000 - Train Loss: 0.0024, Train Acc: 0.9915, Val Loss: 0.0024, Val Acc: 0.9909
# Epoch 278/20000 - Train Loss: 0.0024, Train Acc: 0.9915, Val Loss: 0.0024, Val Acc: 0.9909
# Epoch 279/20000 - Train Loss: 0.0024, Train Acc: 0.9915, Val Loss: 0.0024, Val Acc: 0.9910
# Epoch 280/20000 - Train Loss: 0.0024, Train Acc: 0.9916, Val Loss: 0.0024, Val Acc: 0.9910
# Epoch 281/20000 - Train Loss: 0.0024, Train Acc: 0.9916, Val Loss: 0.0024, Val Acc: 0.9910
# Epoch 282/20000 - Train Loss: 0.0024, Train Acc: 0.9916, Val Loss: 0.0024, Val Acc: 0.9910
# Epoch 283/20000 - Train Loss: 0.0024, Train Acc: 0.9916, Val Loss: 0.0024, Val Acc: 0.9910
# Epoch 284/20000 - Train Loss: 0.0024, Train Acc: 0.9917, Val Loss: 0.0024, Val Acc: 0.9911
# Epoch 285/20000 - Train Loss: 0.0024, Train Acc: 0.9917, Val Loss: 0.0024, Val Acc: 0.9911
# Epoch 286/20000 - Train Loss: 0.0024, Train Acc: 0.9917, Val Loss: 0.0024, Val Acc: 0.9911
# Epoch 287/20000 - Train Loss: 0.0024, Train Acc: 0.9917, Val Loss: 0.0024, Val Acc: 0.9911
# Epoch 288/20000 - Train Loss: 0.0024, Train Acc: 0.9917, Val Loss: 0.0024, Val Acc: 0.9912
# Epoch 289/20000 - Train Loss: 0.0024, Train Acc: 0.9918, Val Loss: 0.0024, Val Acc: 0.9912
# Epoch 290/20000 - Train Loss: 0.0024, Train Acc: 0.9918, Val Loss: 0.0024, Val Acc: 0.9912
# Epoch 291/20000 - Train Loss: 0.0024, Train Acc: 0.9918, Val Loss: 0.0024, Val Acc: 0.9912
# Epoch 292/20000 - Train Loss: 0.0024, Train Acc: 0.9918, Val Loss: 0.0024, Val Acc: 0.9912
# Epoch 293/20000 - Train Loss: 0.0024, Train Acc: 0.9918, Val Loss: 0.0024, Val Acc: 0.9913
# Epoch 294/20000 - Train Loss: 0.0024, Train Acc: 0.9919, Val Loss: 0.0024, Val Acc: 0.9913
# Epoch 295/20000 - Train Loss: 0.0023, Train Acc: 0.9919, Val Loss: 0.0024, Val Acc: 0.9913
# Epoch 296/20000 - Train Loss: 0.0023, Train Acc: 0.9919, Val Loss: 0.0024, Val Acc: 0.9913
# Epoch 297/20000 - Train Loss: 0.0023, Train Acc: 0.9919, Val Loss: 0.0024, Val Acc: 0.9914
# Epoch 298/20000 - Train Loss: 0.0023, Train Acc: 0.9919, Val Loss: 0.0024, Val Acc: 0.9914
# Epoch 299/20000 - Train Loss: 0.0023, Train Acc: 0.9920, Val Loss: 0.0024, Val Acc: 0.9914
# Epoch 300/20000 - Train Loss: 0.0023, Train Acc: 0.9920, Val Loss: 0.0024, Val Acc: 0.9914
# Epoch 301/20000 - Train Loss: 0.0023, Train Acc: 0.9920, Val Loss: 0.0024, Val Acc: 0.9914
# Epoch 302/20000 - Train Loss: 0.0023, Train Acc: 0.9920, Val Loss: 0.0024, Val Acc: 0.9915
# Epoch 303/20000 - Train Loss: 0.0023, Train Acc: 0.9921, Val Loss: 0.0024, Val Acc: 0.9915
# Epoch 304/20000 - Train Loss: 0.0023, Train Acc: 0.9921, Val Loss: 0.0024, Val Acc: 0.9915
# Epoch 305/20000 - Train Loss: 0.0023, Train Acc: 0.9921, Val Loss: 0.0023, Val Acc: 0.9915
# Epoch 306/20000 - Train Loss: 0.0023, Train Acc: 0.9921, Val Loss: 0.0023, Val Acc: 0.9915
# Epoch 307/20000 - Train Loss: 0.0023, Train Acc: 0.9921, Val Loss: 0.0023, Val Acc: 0.9916
# Epoch 308/20000 - Train Loss: 0.0023, Train Acc: 0.9922, Val Loss: 0.0023, Val Acc: 0.9916
# Epoch 309/20000 - Train Loss: 0.0023, Train Acc: 0.9922, Val Loss: 0.0023, Val Acc: 0.9916
# Epoch 310/20000 - Train Loss: 0.0023, Train Acc: 0.9922, Val Loss: 0.0023, Val Acc: 0.9916
# Epoch 311/20000 - Train Loss: 0.0023, Train Acc: 0.9922, Val Loss: 0.0023, Val Acc: 0.9916
# Epoch 312/20000 - Train Loss: 0.0023, Train Acc: 0.9922, Val Loss: 0.0023, Val Acc: 0.9917
# Epoch 313/20000 - Train Loss: 0.0023, Train Acc: 0.9923, Val Loss: 0.0023, Val Acc: 0.9917
# Epoch 314/20000 - Train Loss: 0.0023, Train Acc: 0.9923, Val Loss: 0.0023, Val Acc: 0.9917
# Epoch 315/20000 - Train Loss: 0.0023, Train Acc: 0.9923, Val Loss: 0.0023, Val Acc: 0.9917
# Epoch 316/20000 - Train Loss: 0.0023, Train Acc: 0.9923, Val Loss: 0.0023, Val Acc: 0.9918
# Epoch 317/20000 - Train Loss: 0.0023, Train Acc: 0.9923, Val Loss: 0.0023, Val Acc: 0.9918
# Epoch 318/20000 - Train Loss: 0.0023, Train Acc: 0.9923, Val Loss: 0.0023, Val Acc: 0.9918
# Epoch 319/20000 - Train Loss: 0.0023, Train Acc: 0.9924, Val Loss: 0.0023, Val Acc: 0.9918
# Epoch 320/20000 - Train Loss: 0.0023, Train Acc: 0.9924, Val Loss: 0.0023, Val Acc: 0.9918
# Epoch 321/20000 - Train Loss: 0.0023, Train Acc: 0.9924, Val Loss: 0.0023, Val Acc: 0.9919
# Epoch 322/20000 - Train Loss: 0.0023, Train Acc: 0.9924, Val Loss: 0.0023, Val Acc: 0.9919
# Epoch 323/20000 - Train Loss: 0.0023, Train Acc: 0.9924, Val Loss: 0.0023, Val Acc: 0.9919
# Epoch 324/20000 - Train Loss: 0.0023, Train Acc: 0.9925, Val Loss: 0.0023, Val Acc: 0.9919
# Epoch 325/20000 - Train Loss: 0.0022, Train Acc: 0.9925, Val Loss: 0.0023, Val Acc: 0.9919
# Epoch 326/20000 - Train Loss: 0.0022, Train Acc: 0.9925, Val Loss: 0.0023, Val Acc: 0.9920
# Epoch 327/20000 - Train Loss: 0.0022, Train Acc: 0.9925, Val Loss: 0.0023, Val Acc: 0.9920
# Epoch 328/20000 - Train Loss: 0.0022, Train Acc: 0.9925, Val Loss: 0.0023, Val Acc: 0.9920
# Epoch 329/20000 - Train Loss: 0.0022, Train Acc: 0.9926, Val Loss: 0.0023, Val Acc: 0.9920
# Epoch 330/20000 - Train Loss: 0.0022, Train Acc: 0.9926, Val Loss: 0.0023, Val Acc: 0.9920
# Epoch 331/20000 - Train Loss: 0.0022, Train Acc: 0.9926, Val Loss: 0.0023, Val Acc: 0.9920
# Epoch 332/20000 - Train Loss: 0.0022, Train Acc: 0.9926, Val Loss: 0.0023, Val Acc: 0.9921
# Epoch 333/20000 - Train Loss: 0.0022, Train Acc: 0.9926, Val Loss: 0.0023, Val Acc: 0.9921
# Epoch 334/20000 - Train Loss: 0.0022, Train Acc: 0.9927, Val Loss: 0.0023, Val Acc: 0.9921
# Epoch 335/20000 - Train Loss: 0.0022, Train Acc: 0.9927, Val Loss: 0.0022, Val Acc: 0.9921
# Epoch 336/20000 - Train Loss: 0.0022, Train Acc: 0.9927, Val Loss: 0.0022, Val Acc: 0.9921
# Epoch 337/20000 - Train Loss: 0.0022, Train Acc: 0.9927, Val Loss: 0.0022, Val Acc: 0.9922
# Epoch 338/20000 - Train Loss: 0.0022, Train Acc: 0.9927, Val Loss: 0.0022, Val Acc: 0.9922
# Epoch 339/20000 - Train Loss: 0.0022, Train Acc: 0.9927, Val Loss: 0.0022, Val Acc: 0.9922
# Epoch 340/20000 - Train Loss: 0.0022, Train Acc: 0.9928, Val Loss: 0.0022, Val Acc: 0.9922
# Epoch 341/20000 - Train Loss: 0.0022, Train Acc: 0.9928, Val Loss: 0.0022, Val Acc: 0.9922
# Epoch 342/20000 - Train Loss: 0.0022, Train Acc: 0.9928, Val Loss: 0.0022, Val Acc: 0.9923
# Epoch 343/20000 - Train Loss: 0.0022, Train Acc: 0.9928, Val Loss: 0.0022, Val Acc: 0.9923
# Epoch 344/20000 - Train Loss: 0.0022, Train Acc: 0.9928, Val Loss: 0.0022, Val Acc: 0.9923
# Epoch 345/20000 - Train Loss: 0.0022, Train Acc: 0.9929, Val Loss: 0.0022, Val Acc: 0.9923
# Epoch 346/20000 - Train Loss: 0.0022, Train Acc: 0.9929, Val Loss: 0.0022, Val Acc: 0.9923
# Epoch 347/20000 - Train Loss: 0.0022, Train Acc: 0.9929, Val Loss: 0.0022, Val Acc: 0.9924
# Epoch 348/20000 - Train Loss: 0.0022, Train Acc: 0.9929, Val Loss: 0.0022, Val Acc: 0.9924
# Epoch 349/20000 - Train Loss: 0.0022, Train Acc: 0.9929, Val Loss: 0.0022, Val Acc: 0.9924
# Epoch 350/20000 - Train Loss: 0.0022, Train Acc: 0.9929, Val Loss: 0.0022, Val Acc: 0.9924
# Epoch 351/20000 - Train Loss: 0.0022, Train Acc: 0.9930, Val Loss: 0.0022, Val Acc: 0.9924
# Epoch 352/20000 - Train Loss: 0.0022, Train Acc: 0.9930, Val Loss: 0.0022, Val Acc: 0.9924
# Epoch 353/20000 - Train Loss: 0.0022, Train Acc: 0.9930, Val Loss: 0.0022, Val Acc: 0.9925
# Epoch 354/20000 - Train Loss: 0.0022, Train Acc: 0.9930, Val Loss: 0.0022, Val Acc: 0.9925
# Epoch 355/20000 - Train Loss: 0.0022, Train Acc: 0.9930, Val Loss: 0.0022, Val Acc: 0.9925
# Epoch 356/20000 - Train Loss: 0.0022, Train Acc: 0.9930, Val Loss: 0.0022, Val Acc: 0.9925
# Epoch 357/20000 - Train Loss: 0.0021, Train Acc: 0.9931, Val Loss: 0.0022, Val Acc: 0.9925
# Epoch 358/20000 - Train Loss: 0.0021, Train Acc: 0.9931, Val Loss: 0.0022, Val Acc: 0.9926
# Epoch 359/20000 - Train Loss: 0.0021, Train Acc: 0.9931, Val Loss: 0.0022, Val Acc: 0.9926
# Epoch 360/20000 - Train Loss: 0.0021, Train Acc: 0.9931, Val Loss: 0.0022, Val Acc: 0.9926
# Epoch 361/20000 - Train Loss: 0.0021, Train Acc: 0.9931, Val Loss: 0.0022, Val Acc: 0.9926
# Epoch 362/20000 - Train Loss: 0.0021, Train Acc: 0.9931, Val Loss: 0.0022, Val Acc: 0.9926
# Epoch 363/20000 - Train Loss: 0.0021, Train Acc: 0.9932, Val Loss: 0.0022, Val Acc: 0.9926
# Epoch 364/20000 - Train Loss: 0.0021, Train Acc: 0.9932, Val Loss: 0.0022, Val Acc: 0.9927
# Epoch 365/20000 - Train Loss: 0.0021, Train Acc: 0.9932, Val Loss: 0.0022, Val Acc: 0.9927
# Epoch 366/20000 - Train Loss: 0.0021, Train Acc: 0.9932, Val Loss: 0.0022, Val Acc: 0.9927
# Epoch 367/20000 - Train Loss: 0.0021, Train Acc: 0.9932, Val Loss: 0.0022, Val Acc: 0.9927
# Epoch 368/20000 - Train Loss: 0.0021, Train Acc: 0.9932, Val Loss: 0.0022, Val Acc: 0.9927
# Epoch 369/20000 - Train Loss: 0.0021, Train Acc: 0.9933, Val Loss: 0.0021, Val Acc: 0.9928
# Epoch 370/20000 - Train Loss: 0.0021, Train Acc: 0.9933, Val Loss: 0.0021, Val Acc: 0.9928
# Epoch 371/20000 - Train Loss: 0.0021, Train Acc: 0.9933, Val Loss: 0.0021, Val Acc: 0.9928
# Epoch 372/20000 - Train Loss: 0.0021, Train Acc: 0.9933, Val Loss: 0.0021, Val Acc: 0.9928
# Epoch 373/20000 - Train Loss: 0.0021, Train Acc: 0.9933, Val Loss: 0.0021, Val Acc: 0.9928
# Epoch 374/20000 - Train Loss: 0.0021, Train Acc: 0.9933, Val Loss: 0.0021, Val Acc: 0.9928
# Epoch 375/20000 - Train Loss: 0.0021, Train Acc: 0.9934, Val Loss: 0.0021, Val Acc: 0.9929
# Epoch 376/20000 - Train Loss: 0.0021, Train Acc: 0.9934, Val Loss: 0.0021, Val Acc: 0.9929
# Epoch 377/20000 - Train Loss: 0.0021, Train Acc: 0.9934, Val Loss: 0.0021, Val Acc: 0.9929
# Epoch 378/20000 - Train Loss: 0.0021, Train Acc: 0.9934, Val Loss: 0.0021, Val Acc: 0.9929
# Epoch 379/20000 - Train Loss: 0.0021, Train Acc: 0.9934, Val Loss: 0.0021, Val Acc: 0.9929
# Epoch 380/20000 - Train Loss: 0.0021, Train Acc: 0.9934, Val Loss: 0.0021, Val Acc: 0.9929
# Epoch 381/20000 - Train Loss: 0.0021, Train Acc: 0.9935, Val Loss: 0.0021, Val Acc: 0.9930
# Epoch 382/20000 - Train Loss: 0.0021, Train Acc: 0.9935, Val Loss: 0.0021, Val Acc: 0.9930
# Epoch 383/20000 - Train Loss: 0.0021, Train Acc: 0.9935, Val Loss: 0.0021, Val Acc: 0.9930
# Epoch 384/20000 - Train Loss: 0.0021, Train Acc: 0.9935, Val Loss: 0.0021, Val Acc: 0.9930
# Epoch 385/20000 - Train Loss: 0.0021, Train Acc: 0.9935, Val Loss: 0.0021, Val Acc: 0.9930
# Epoch 386/20000 - Train Loss: 0.0021, Train Acc: 0.9935, Val Loss: 0.0021, Val Acc: 0.9930
# Epoch 387/20000 - Train Loss: 0.0021, Train Acc: 0.9935, Val Loss: 0.0021, Val Acc: 0.9931
# Epoch 388/20000 - Train Loss: 0.0021, Train Acc: 0.9936, Val Loss: 0.0021, Val Acc: 0.9931
# Epoch 389/20000 - Train Loss: 0.0021, Train Acc: 0.9936, Val Loss: 0.0021, Val Acc: 0.9931
# Epoch 390/20000 - Train Loss: 0.0021, Train Acc: 0.9936, Val Loss: 0.0021, Val Acc: 0.9931
# Epoch 391/20000 - Train Loss: 0.0021, Train Acc: 0.9936, Val Loss: 0.0021, Val Acc: 0.9931
# Epoch 392/20000 - Train Loss: 0.0021, Train Acc: 0.9936, Val Loss: 0.0021, Val Acc: 0.9931
# Epoch 393/20000 - Train Loss: 0.0020, Train Acc: 0.9936, Val Loss: 0.0021, Val Acc: 0.9932
# Epoch 394/20000 - Train Loss: 0.0020, Train Acc: 0.9937, Val Loss: 0.0021, Val Acc: 0.9932
# Epoch 395/20000 - Train Loss: 0.0020, Train Acc: 0.9937, Val Loss: 0.0021, Val Acc: 0.9932
# Epoch 396/20000 - Train Loss: 0.0020, Train Acc: 0.9937, Val Loss: 0.0021, Val Acc: 0.9932
# Epoch 397/20000 - Train Loss: 0.0020, Train Acc: 0.9937, Val Loss: 0.0021, Val Acc: 0.9932
# Epoch 398/20000 - Train Loss: 0.0020, Train Acc: 0.9937, Val Loss: 0.0021, Val Acc: 0.9932
# Epoch 399/20000 - Train Loss: 0.0020, Train Acc: 0.9937, Val Loss: 0.0021, Val Acc: 0.9932
# Epoch 400/20000 - Train Loss: 0.0020, Train Acc: 0.9937, Val Loss: 0.0021, Val Acc: 0.9933
# Epoch 401/20000 - Train Loss: 0.0020, Train Acc: 0.9938, Val Loss: 0.0021, Val Acc: 0.9933
# Epoch 402/20000 - Train Loss: 0.0020, Train Acc: 0.9938, Val Loss: 0.0021, Val Acc: 0.9933
# Epoch 403/20000 - Train Loss: 0.0020, Train Acc: 0.9938, Val Loss: 0.0021, Val Acc: 0.9933
# Epoch 404/20000 - Train Loss: 0.0020, Train Acc: 0.9938, Val Loss: 0.0021, Val Acc: 0.9933
# Epoch 405/20000 - Train Loss: 0.0020, Train Acc: 0.9938, Val Loss: 0.0021, Val Acc: 0.9933
# Epoch 406/20000 - Train Loss: 0.0020, Train Acc: 0.9938, Val Loss: 0.0020, Val Acc: 0.9934
# Epoch 407/20000 - Train Loss: 0.0020, Train Acc: 0.9938, Val Loss: 0.0020, Val Acc: 0.9934
# Epoch 408/20000 - Train Loss: 0.0020, Train Acc: 0.9939, Val Loss: 0.0020, Val Acc: 0.9934
# Epoch 409/20000 - Train Loss: 0.0020, Train Acc: 0.9939, Val Loss: 0.0020, Val Acc: 0.9934
# Epoch 410/20000 - Train Loss: 0.0020, Train Acc: 0.9939, Val Loss: 0.0020, Val Acc: 0.9934
# Epoch 411/20000 - Train Loss: 0.0020, Train Acc: 0.9939, Val Loss: 0.0020, Val Acc: 0.9934
# Epoch 412/20000 - Train Loss: 0.0020, Train Acc: 0.9939, Val Loss: 0.0020, Val Acc: 0.9934
# Epoch 413/20000 - Train Loss: 0.0020, Train Acc: 0.9939, Val Loss: 0.0020, Val Acc: 0.9935
# Epoch 414/20000 - Train Loss: 0.0020, Train Acc: 0.9939, Val Loss: 0.0020, Val Acc: 0.9935
# Epoch 415/20000 - Train Loss: 0.0020, Train Acc: 0.9940, Val Loss: 0.0020, Val Acc: 0.9935
# Epoch 416/20000 - Train Loss: 0.0020, Train Acc: 0.9940, Val Loss: 0.0020, Val Acc: 0.9935
# Epoch 417/20000 - Train Loss: 0.0020, Train Acc: 0.9940, Val Loss: 0.0020, Val Acc: 0.9935
# Epoch 418/20000 - Train Loss: 0.0020, Train Acc: 0.9940, Val Loss: 0.0020, Val Acc: 0.9935
# Epoch 419/20000 - Train Loss: 0.0020, Train Acc: 0.9940, Val Loss: 0.0020, Val Acc: 0.9935
# Epoch 420/20000 - Train Loss: 0.0020, Train Acc: 0.9940, Val Loss: 0.0020, Val Acc: 0.9936
# Epoch 421/20000 - Train Loss: 0.0020, Train Acc: 0.9940, Val Loss: 0.0020, Val Acc: 0.9936
# Epoch 422/20000 - Train Loss: 0.0020, Train Acc: 0.9941, Val Loss: 0.0020, Val Acc: 0.9936
# Epoch 423/20000 - Train Loss: 0.0020, Train Acc: 0.9941, Val Loss: 0.0020, Val Acc: 0.9936
# Epoch 424/20000 - Train Loss: 0.0020, Train Acc: 0.9941, Val Loss: 0.0020, Val Acc: 0.9936
# Epoch 425/20000 - Train Loss: 0.0020, Train Acc: 0.9941, Val Loss: 0.0020, Val Acc: 0.9936
# Epoch 426/20000 - Train Loss: 0.0020, Train Acc: 0.9941, Val Loss: 0.0020, Val Acc: 0.9936
# Epoch 427/20000 - Train Loss: 0.0020, Train Acc: 0.9941, Val Loss: 0.0020, Val Acc: 0.9937
# Epoch 428/20000 - Train Loss: 0.0020, Train Acc: 0.9941, Val Loss: 0.0020, Val Acc: 0.9937
# Epoch 429/20000 - Train Loss: 0.0020, Train Acc: 0.9941, Val Loss: 0.0020, Val Acc: 0.9937
# Epoch 430/20000 - Train Loss: 0.0020, Train Acc: 0.9942, Val Loss: 0.0020, Val Acc: 0.9937
# Epoch 431/20000 - Train Loss: 0.0020, Train Acc: 0.9942, Val Loss: 0.0020, Val Acc: 0.9937
# Epoch 432/20000 - Train Loss: 0.0020, Train Acc: 0.9942, Val Loss: 0.0020, Val Acc: 0.9937
# Epoch 433/20000 - Train Loss: 0.0020, Train Acc: 0.9942, Val Loss: 0.0020, Val Acc: 0.9937
# Epoch 434/20000 - Train Loss: 0.0020, Train Acc: 0.9942, Val Loss: 0.0020, Val Acc: 0.9938
# Epoch 435/20000 - Train Loss: 0.0020, Train Acc: 0.9942, Val Loss: 0.0020, Val Acc: 0.9938
# Epoch 436/20000 - Train Loss: 0.0019, Train Acc: 0.9942, Val Loss: 0.0020, Val Acc: 0.9938
# Epoch 437/20000 - Train Loss: 0.0019, Train Acc: 0.9942, Val Loss: 0.0020, Val Acc: 0.9938
# Epoch 438/20000 - Train Loss: 0.0019, Train Acc: 0.9943, Val Loss: 0.0020, Val Acc: 0.9938
# Epoch 439/20000 - Train Loss: 0.0019, Train Acc: 0.9943, Val Loss: 0.0020, Val Acc: 0.9938
# Epoch 440/20000 - Train Loss: 0.0019, Train Acc: 0.9943, Val Loss: 0.0020, Val Acc: 0.9938
# Epoch 441/20000 - Train Loss: 0.0019, Train Acc: 0.9943, Val Loss: 0.0020, Val Acc: 0.9938
# Epoch 442/20000 - Train Loss: 0.0019, Train Acc: 0.9943, Val Loss: 0.0020, Val Acc: 0.9939
# Epoch 443/20000 - Train Loss: 0.0019, Train Acc: 0.9943, Val Loss: 0.0020, Val Acc: 0.9939
# Epoch 444/20000 - Train Loss: 0.0019, Train Acc: 0.9943, Val Loss: 0.0020, Val Acc: 0.9939
# Epoch 445/20000 - Train Loss: 0.0019, Train Acc: 0.9943, Val Loss: 0.0020, Val Acc: 0.9939
# Epoch 446/20000 - Train Loss: 0.0019, Train Acc: 0.9944, Val Loss: 0.0020, Val Acc: 0.9939
# Epoch 447/20000 - Train Loss: 0.0019, Train Acc: 0.9944, Val Loss: 0.0020, Val Acc: 0.9939
# Epoch 448/20000 - Train Loss: 0.0019, Train Acc: 0.9944, Val Loss: 0.0020, Val Acc: 0.9939
# Epoch 449/20000 - Train Loss: 0.0019, Train Acc: 0.9944, Val Loss: 0.0020, Val Acc: 0.9939
# Epoch 450/20000 - Train Loss: 0.0019, Train Acc: 0.9944, Val Loss: 0.0019, Val Acc: 0.9940
# Epoch 451/20000 - Train Loss: 0.0019, Train Acc: 0.9944, Val Loss: 0.0019, Val Acc: 0.9940
# Epoch 452/20000 - Train Loss: 0.0019, Train Acc: 0.9944, Val Loss: 0.0019, Val Acc: 0.9940
# Epoch 453/20000 - Train Loss: 0.0019, Train Acc: 0.9944, Val Loss: 0.0019, Val Acc: 0.9940
# Epoch 454/20000 - Train Loss: 0.0019, Train Acc: 0.9944, Val Loss: 0.0019, Val Acc: 0.9940
# Epoch 455/20000 - Train Loss: 0.0019, Train Acc: 0.9945, Val Loss: 0.0019, Val Acc: 0.9940
# Epoch 456/20000 - Train Loss: 0.0019, Train Acc: 0.9945, Val Loss: 0.0019, Val Acc: 0.9940
# Epoch 457/20000 - Train Loss: 0.0019, Train Acc: 0.9945, Val Loss: 0.0019, Val Acc: 0.9940
# Epoch 458/20000 - Train Loss: 0.0019, Train Acc: 0.9945, Val Loss: 0.0019, Val Acc: 0.9941
# Epoch 459/20000 - Train Loss: 0.0019, Train Acc: 0.9945, Val Loss: 0.0019, Val Acc: 0.9941
# Epoch 460/20000 - Train Loss: 0.0019, Train Acc: 0.9945, Val Loss: 0.0019, Val Acc: 0.9941
# Epoch 461/20000 - Train Loss: 0.0019, Train Acc: 0.9945, Val Loss: 0.0019, Val Acc: 0.9941
# Epoch 462/20000 - Train Loss: 0.0019, Train Acc: 0.9945, Val Loss: 0.0019, Val Acc: 0.9941
# Epoch 463/20000 - Train Loss: 0.0019, Train Acc: 0.9946, Val Loss: 0.0019, Val Acc: 0.9941
# Epoch 464/20000 - Train Loss: 0.0019, Train Acc: 0.9946, Val Loss: 0.0019, Val Acc: 0.9941
# Epoch 465/20000 - Train Loss: 0.0019, Train Acc: 0.9946, Val Loss: 0.0019, Val Acc: 0.9941
# Epoch 466/20000 - Train Loss: 0.0019, Train Acc: 0.9946, Val Loss: 0.0019, Val Acc: 0.9942
# Epoch 467/20000 - Train Loss: 0.0019, Train Acc: 0.9946, Val Loss: 0.0019, Val Acc: 0.9942
# Epoch 468/20000 - Train Loss: 0.0019, Train Acc: 0.9946, Val Loss: 0.0019, Val Acc: 0.9942
# Epoch 469/20000 - Train Loss: 0.0019, Train Acc: 0.9946, Val Loss: 0.0019, Val Acc: 0.9942
# Epoch 470/20000 - Train Loss: 0.0019, Train Acc: 0.9946, Val Loss: 0.0019, Val Acc: 0.9942
# Epoch 471/20000 - Train Loss: 0.0019, Train Acc: 0.9946, Val Loss: 0.0019, Val Acc: 0.9942
# Epoch 472/20000 - Train Loss: 0.0019, Train Acc: 0.9946, Val Loss: 0.0019, Val Acc: 0.9942
# Epoch 473/20000 - Train Loss: 0.0019, Train Acc: 0.9947, Val Loss: 0.0019, Val Acc: 0.9942
# Epoch 474/20000 - Train Loss: 0.0019, Train Acc: 0.9947, Val Loss: 0.0019, Val Acc: 0.9942
# Epoch 475/20000 - Train Loss: 0.0019, Train Acc: 0.9947, Val Loss: 0.0019, Val Acc: 0.9943
# Epoch 476/20000 - Train Loss: 0.0019, Train Acc: 0.9947, Val Loss: 0.0019, Val Acc: 0.9943
# Epoch 477/20000 - Train Loss: 0.0019, Train Acc: 0.9947, Val Loss: 0.0019, Val Acc: 0.9943
# Epoch 478/20000 - Train Loss: 0.0019, Train Acc: 0.9947, Val Loss: 0.0019, Val Acc: 0.9943
# Epoch 479/20000 - Train Loss: 0.0019, Train Acc: 0.9947, Val Loss: 0.0019, Val Acc: 0.9943
# Epoch 480/20000 - Train Loss: 0.0019, Train Acc: 0.9947, Val Loss: 0.0019, Val Acc: 0.9943
# Epoch 481/20000 - Train Loss: 0.0019, Train Acc: 0.9947, Val Loss: 0.0019, Val Acc: 0.9943
# Epoch 482/20000 - Train Loss: 0.0019, Train Acc: 0.9947, Val Loss: 0.0019, Val Acc: 0.9943
# Epoch 483/20000 - Train Loss: 0.0019, Train Acc: 0.9948, Val Loss: 0.0019, Val Acc: 0.9943
# Epoch 484/20000 - Train Loss: 0.0019, Train Acc: 0.9948, Val Loss: 0.0019, Val Acc: 0.9944
# Epoch 485/20000 - Train Loss: 0.0019, Train Acc: 0.9948, Val Loss: 0.0019, Val Acc: 0.9944
# Epoch 486/20000 - Train Loss: 0.0019, Train Acc: 0.9948, Val Loss: 0.0019, Val Acc: 0.9944
# Epoch 487/20000 - Train Loss: 0.0018, Train Acc: 0.9948, Val Loss: 0.0019, Val Acc: 0.9944
# Epoch 488/20000 - Train Loss: 0.0018, Train Acc: 0.9948, Val Loss: 0.0019, Val Acc: 0.9944
# Epoch 489/20000 - Train Loss: 0.0018, Train Acc: 0.9948, Val Loss: 0.0019, Val Acc: 0.9944
# Epoch 490/20000 - Train Loss: 0.0018, Train Acc: 0.9948, Val Loss: 0.0019, Val Acc: 0.9944
# Epoch 491/20000 - Train Loss: 0.0018, Train Acc: 0.9948, Val Loss: 0.0019, Val Acc: 0.9944
# Epoch 492/20000 - Train Loss: 0.0018, Train Acc: 0.9948, Val Loss: 0.0019, Val Acc: 0.9944
# Epoch 493/20000 - Train Loss: 0.0018, Train Acc: 0.9949, Val Loss: 0.0019, Val Acc: 0.9944
# Epoch 494/20000 - Train Loss: 0.0018, Train Acc: 0.9949, Val Loss: 0.0019, Val Acc: 0.9945
# Epoch 495/20000 - Train Loss: 0.0018, Train Acc: 0.9949, Val Loss: 0.0019, Val Acc: 0.9945
# Epoch 496/20000 - Train Loss: 0.0018, Train Acc: 0.9949, Val Loss: 0.0019, Val Acc: 0.9945
# Epoch 497/20000 - Train Loss: 0.0018, Train Acc: 0.9949, Val Loss: 0.0019, Val Acc: 0.9945
# Epoch 498/20000 - Train Loss: 0.0018, Train Acc: 0.9949, Val Loss: 0.0019, Val Acc: 0.9945
# Epoch 499/20000 - Train Loss: 0.0018, Train Acc: 0.9949, Val Loss: 0.0019, Val Acc: 0.9945
# Epoch 500/20000 - Train Loss: 0.0018, Train Acc: 0.9949, Val Loss: 0.0019, Val Acc: 0.9945
# Epoch 501/20000 - Train Loss: 0.0018, Train Acc: 0.9949, Val Loss: 0.0019, Val Acc: 0.9945
# Epoch 502/20000 - Train Loss: 0.0018, Train Acc: 0.9949, Val Loss: 0.0019, Val Acc: 0.9945
# Epoch 503/20000 - Train Loss: 0.0018, Train Acc: 0.9949, Val Loss: 0.0019, Val Acc: 0.9945
# Epoch 504/20000 - Train Loss: 0.0018, Train Acc: 0.9950, Val Loss: 0.0018, Val Acc: 0.9946
# Epoch 505/20000 - Train Loss: 0.0018, Train Acc: 0.9950, Val Loss: 0.0018, Val Acc: 0.9946
# Epoch 506/20000 - Train Loss: 0.0018, Train Acc: 0.9950, Val Loss: 0.0018, Val Acc: 0.9946
# Epoch 507/20000 - Train Loss: 0.0018, Train Acc: 0.9950, Val Loss: 0.0018, Val Acc: 0.9946
# Epoch 508/20000 - Train Loss: 0.0018, Train Acc: 0.9950, Val Loss: 0.0018, Val Acc: 0.9946
# Epoch 509/20000 - Train Loss: 0.0018, Train Acc: 0.9950, Val Loss: 0.0018, Val Acc: 0.9946
# Epoch 510/20000 - Train Loss: 0.0018, Train Acc: 0.9950, Val Loss: 0.0018, Val Acc: 0.9946
# Epoch 511/20000 - Train Loss: 0.0018, Train Acc: 0.9950, Val Loss: 0.0018, Val Acc: 0.9946
# Epoch 512/20000 - Train Loss: 0.0018, Train Acc: 0.9950, Val Loss: 0.0018, Val Acc: 0.9946
# Epoch 513/20000 - Train Loss: 0.0018, Train Acc: 0.9950, Val Loss: 0.0018, Val Acc: 0.9946
# Epoch 514/20000 - Train Loss: 0.0018, Train Acc: 0.9950, Val Loss: 0.0018, Val Acc: 0.9946
# Epoch 515/20000 - Train Loss: 0.0018, Train Acc: 0.9951, Val Loss: 0.0018, Val Acc: 0.9947
# Epoch 516/20000 - Train Loss: 0.0018, Train Acc: 0.9951, Val Loss: 0.0018, Val Acc: 0.9947
# Epoch 517/20000 - Train Loss: 0.0018, Train Acc: 0.9951, Val Loss: 0.0018, Val Acc: 0.9947
# Epoch 518/20000 - Train Loss: 0.0018, Train Acc: 0.9951, Val Loss: 0.0018, Val Acc: 0.9947
# Epoch 519/20000 - Train Loss: 0.0018, Train Acc: 0.9951, Val Loss: 0.0018, Val Acc: 0.9947
# Epoch 520/20000 - Train Loss: 0.0018, Train Acc: 0.9951, Val Loss: 0.0018, Val Acc: 0.9947
# Epoch 521/20000 - Train Loss: 0.0018, Train Acc: 0.9951, Val Loss: 0.0018, Val Acc: 0.9947
# Epoch 522/20000 - Train Loss: 0.0018, Train Acc: 0.9951, Val Loss: 0.0018, Val Acc: 0.9947
# Epoch 523/20000 - Train Loss: 0.0018, Train Acc: 0.9951, Val Loss: 0.0018, Val Acc: 0.9947
# Epoch 524/20000 - Train Loss: 0.0018, Train Acc: 0.9951, Val Loss: 0.0018, Val Acc: 0.9947
# Epoch 525/20000 - Train Loss: 0.0018, Train Acc: 0.9951, Val Loss: 0.0018, Val Acc: 0.9947
# Epoch 526/20000 - Train Loss: 0.0018, Train Acc: 0.9951, Val Loss: 0.0018, Val Acc: 0.9947
# Epoch 527/20000 - Train Loss: 0.0018, Train Acc: 0.9951, Val Loss: 0.0018, Val Acc: 0.9948
# Epoch 528/20000 - Train Loss: 0.0018, Train Acc: 0.9952, Val Loss: 0.0018, Val Acc: 0.9948
# ...
# Epoch 19829/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19830/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19831/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19832/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19833/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19834/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19835/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19836/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19837/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19838/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19839/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19840/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19841/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19842/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19843/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19844/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19845/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19846/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19847/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19848/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19849/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19850/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19851/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19852/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19853/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19854/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19855/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19856/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19857/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19858/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19859/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19860/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19861/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19862/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19863/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19864/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19865/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19866/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19867/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19868/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19869/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19870/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19871/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9977
# Epoch 19872/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9977
# Epoch 19873/20000 - Train Loss: 0.0007, Train Acc: 0.9977, Val Loss: 0.0007, Val Acc: 0.9975
# Epoch 19874/20000 - Train Loss: 0.0007, Train Acc: 0.9976, Val Loss: 0.0008, Val Acc: 0.9975
# Epoch 19875/20000 - Train Loss: 0.0008, Train Acc: 0.9975, Val Loss: 0.0008, Val Acc: 0.9972
# Epoch 19876/20000 - Train Loss: 0.0008, Train Acc: 0.9973, Val Loss: 0.0008, Val Acc: 0.9972
# Epoch 19877/20000 - Train Loss: 0.0008, Train Acc: 0.9972, Val Loss: 0.0008, Val Acc: 0.9969
# Epoch 19878/20000 - Train Loss: 0.0008, Train Acc: 0.9971, Val Loss: 0.0008, Val Acc: 0.9971
# Epoch 19879/20000 - Train Loss: 0.0008, Train Acc: 0.9971, Val Loss: 0.0008, Val Acc: 0.9973
# Epoch 19880/20000 - Train Loss: 0.0008, Train Acc: 0.9974, Val Loss: 0.0007, Val Acc: 0.9976
# Epoch 19881/20000 - Train Loss: 0.0007, Train Acc: 0.9977, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19882/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9977
# Epoch 19883/20000 - Train Loss: 0.0007, Train Acc: 0.9977, Val Loss: 0.0007, Val Acc: 0.9975
# Epoch 19884/20000 - Train Loss: 0.0008, Train Acc: 0.9975, Val Loss: 0.0008, Val Acc: 0.9974
# Epoch 19885/20000 - Train Loss: 0.0008, Train Acc: 0.9975, Val Loss: 0.0007, Val Acc: 0.9976
# Epoch 19886/20000 - Train Loss: 0.0007, Train Acc: 0.9976, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19887/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19888/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9977
# Epoch 19889/20000 - Train Loss: 0.0007, Train Acc: 0.9977, Val Loss: 0.0007, Val Acc: 0.9976
# Epoch 19890/20000 - Train Loss: 0.0007, Train Acc: 0.9976, Val Loss: 0.0007, Val Acc: 0.9977
# Epoch 19891/20000 - Train Loss: 0.0007, Train Acc: 0.9977, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19892/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19893/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9977
# Epoch 19894/20000 - Train Loss: 0.0007, Train Acc: 0.9977, Val Loss: 0.0007, Val Acc: 0.9977
# Epoch 19895/20000 - Train Loss: 0.0007, Train Acc: 0.9977, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19896/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19897/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19898/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19899/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9977
# Epoch 19900/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19901/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19902/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19903/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19904/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9977
# Epoch 19905/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19906/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19907/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19908/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19909/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19910/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19911/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19912/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19913/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19914/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19915/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19916/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19917/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19918/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19919/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19920/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19921/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19922/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19923/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19924/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19925/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19926/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19927/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19928/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19929/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19930/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19931/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19932/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19933/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19934/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19935/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19936/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19937/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19938/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19939/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19940/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19941/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19942/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19943/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19944/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19945/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19946/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19947/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19948/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19949/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19950/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19951/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19952/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19953/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19954/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19955/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19956/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19957/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19958/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19959/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19960/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19961/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19962/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19963/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19964/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19965/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19966/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19967/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19968/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19969/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19970/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19971/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19972/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19973/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19974/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19975/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19976/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19977/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19978/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19979/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19980/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19981/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19982/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19983/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19984/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19985/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19986/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19987/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19988/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19989/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19990/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19991/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19992/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19993/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19994/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19995/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19996/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19997/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19998/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 19999/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978
# Epoch 20000/20000 - Train Loss: 0.0007, Train Acc: 0.9978, Val Loss: 0.0007, Val Acc: 0.9978

# %%
training_losses = nn.training_losses
validation_losses = nn.validation_losses
training_accuracies = nn.training_accuracies
validation_accuracies = nn.validation_accuracies

# Create a figure with 1 row and 2 columns for loss and accuracy plots
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Create a range of epochs for the x-axis
epochs = range(1, len(training_losses) + 1)

# Plot Loss with Logarithmic X-Axis
sns.lineplot(x=epochs, y=training_losses, ax=ax[0], label='Training Loss', color='blue')
sns.lineplot(x=epochs, y=validation_losses, ax=ax[0], label='Validation Loss', color='orange')
ax[0].set_xscale('log')  # Set x-axis to logarithmic scale
ax[0].set_xlabel('Epochs (Log Scale)')
ax[0].set_ylabel('Loss')
ax[0].set_title('Training and Validation Loss')
ax[0].legend()

# Plot Accuracy with Logarithmic X-Axis
sns.lineplot(x=epochs, y=training_accuracies, ax=ax[1], label='Training Accuracy', color='blue')
sns.lineplot(x=epochs, y=validation_accuracies, ax=ax[1], label='Validation Accuracy', color='orange')
ax[1].set_xscale('log')  # Set x-axis to logarithmic scale
ax[1].set_xlabel('Epochs (Log Scale)')
ax[1].set_ylabel('R² Score')
ax[1].set_title('Training and Validation Accuracy (R² Score)')
ax[1].legend()

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

# %%
y_pred_train_norm = nn.predict(X_train_norm)
y_pred_val_norm = nn.predict(X_val_norm)
y_pred_train = scaler.inverse_transform(y_pred_train_norm)
y_pred_val = scaler.inverse_transform(y_pred_val_norm)

# y_pred_train_norm = nn.predict(X_train)
# y_pred_val_norm = nn.predict(X_val)
# y_pred_train = y_pred_train_norm
# y_pred_val = y_pred_val_norm

# %%
# Assuming y_train, y_pred_train, y_val, and y_pred_val are already defined
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Generate time indices for training and validation
train_indices = range(len(y_train))
val_indices = range(len(y_val))

# Plot y_pred_train and y_train over time (k) with reduced alpha for predicted line
sns.lineplot(x=train_indices, y=y_train.flatten(), ax=ax[0], color='blue', label='Actual Train', linewidth=1)
sns.lineplot(x=train_indices, y=y_pred_train.flatten(), ax=ax[0], color='orange', label='Predicted Train', alpha=0.5, linewidth=1)
ax[0].set_xlabel('Time Index (k)')
ax[0].set_ylabel('Values')
ax[0].set_title('Training Data: Actual vs Predicted Over Time')
ax[0].legend()

# Plot y_pred_val and y_val over time (k) with reduced alpha for predicted line
sns.lineplot(x=val_indices, y=y_val.flatten(), ax=ax[1], color='blue', label='Actual Val', linewidth=1)
sns.lineplot(x=val_indices, y=y_pred_val.flatten(), ax=ax[1], color='orange', label='Predicted Val', alpha=0.5, linewidth=1)
ax[1].set_xlabel('Time Index (k)')
ax[1].set_ylabel('Values')
ax[1].set_title('Validation Data: Actual vs Predicted Over Time')
ax[1].legend()

# Show the updated plots
plt.tight_layout()
plt.show()

# %%
weights = nn.get_weights()
biases = nn.get_biases()

# %%
class MLPVectoral:
    def __init__(self, layers, activations, optimizer='adam', learning_rate=0.001, l2_lambda=0.01, weights=None, biases=None):
        self.layers = layers
        self.activations = activations
        self.learning_rate = learning_rate
        self.l2_lambda = l2_lambda  # Regularization parameter
        self.weights = weights if weights else self.initialize_weights()[0]
        self.biases = biases if biases else self.initialize_weights()[1]
        self.optimizer = optimizer
        self.momentum_w, self.momentum_b = None, None
        self.v_w, self.v_b = None, None
        self.initialize_optimizer_parameters()
        # Arrays to store training and validation loss/accuracy
        self.training_losses = []
        self.validation_losses = []
        self.training_accuracies = []
        self.validation_accuracies = []
        # Variables to store the best weights and biases
        self.best_weights = [np.copy(w) for w in self.weights]
        self.best_biases = [np.copy(b) for b in self.biases]
        self.best_loss = float('inf')  # Initialize with a very high value

    def initialize_weights(self):
        weights = []
        biases = []
        for i in range(len(self.layers) - 1):
            input_dim = self.layers[i]
            output_dim = self.layers[i + 1]
            
            # Nguyen-Widrow initialization
            w = np.random.uniform(-1, 1, (input_dim, output_dim))
            beta = 0.7 * output_dim ** (1.0 / input_dim)
            norm = np.linalg.norm(w, axis=0)
            w = beta * (w / norm)
            
            b = np.zeros((1, output_dim))
            weights.append(w)
            biases.append(b)
        
        return weights, biases

    def initialize_optimizer_parameters(self):
        if self.optimizer in ['adam', 'rmsprop']:
            self.momentum_w = [np.zeros_like(w) for w in self.weights]
            self.momentum_b = [np.zeros_like(b) for b in self.biases]
            self.v_w = [np.zeros_like(w) for w in self.weights]
            self.v_b = [np.zeros_like(b) for b in self.biases]

        self.beta1 = 0.9
        self.beta2 = 0.999
        self.epsilon = 1e-8

    def activation(self, x, func):
        if func == 'tanh':
            return np.tanh(x)
        elif func == 'linear':
            return x

    def activation_derivative(self, x, func):
        if func == 'tanh':
            return 1 - np.tanh(x) ** 2
        elif func == 'linear':
            return np.ones_like(x)

    def forward(self, x):
        self.z_list = []
        self.a_list = [x]

        for i in range(len(self.weights)):
            z = np.dot(x, self.weights[i]) + self.biases[i]
            x = self.activation(z, self.activations[i])
            self.z_list.append(z)
            self.a_list.append(x)
        return x

    def backward(self, y_true, y_pred):
        gradients_w = []
        gradients_b = []
        loss_derivative = 2 * (y_pred - y_true)

        # Output layer
        delta = loss_derivative * self.activation_derivative(self.z_list[-1], self.activations[-1])
        grad_w = np.dot(self.a_list[-2].T, delta) + self.l2_lambda * self.weights[-1]
        grad_b = np.sum(delta, axis=0, keepdims=True)

        gradients_w.insert(0, grad_w)
        gradients_b.insert(0, grad_b)

        # Hidden layers
        for i in range(len(self.layers) - 3, -1, -1):
            delta = np.dot(delta, self.weights[i + 1].T) * self.activation_derivative(self.z_list[i], self.activations[i])
            grad_w = np.dot(self.a_list[i].T, delta) + self.l2_lambda * self.weights[i]
            grad_b = np.sum(delta, axis=0, keepdims=True)
            gradients_w.insert(0, grad_w)
            gradients_b.insert(0, grad_b)

        return gradients_w, gradients_b

    def update_weights(self, gradients_w, gradients_b):
        if self.optimizer == 'gradient_descent' or self.optimizer == 'sgd':
            for i in range(len(self.weights)):
                self.weights[i] -= self.learning_rate * gradients_w[i]
                self.biases[i] -= self.learning_rate * gradients_b[i]
        elif self.optimizer == 'rmsprop':
            for i in range(len(self.weights)):
                self.momentum_w[i] = self.beta2 * self.momentum_w[i] + (1 - self.beta2) * gradients_w[i]**2
                self.momentum_b[i] = self.beta2 * self.momentum_b[i] + (1 - self.beta2) * gradients_b[i]**2

                self.weights[i] -= self.learning_rate * gradients_w[i] / (np.sqrt(self.momentum_w[i]) + self.epsilon)
                self.biases[i] -= self.learning_rate * gradients_b[i] / (np.sqrt(self.momentum_b[i]) + self.epsilon)
        elif self.optimizer == 'adam':
            for i in range(len(self.weights)):
                self.momentum_w[i] = self.beta1 * self.momentum_w[i] + (1 - self.beta1) * gradients_w[i]
                self.momentum_b[i] = self.beta1 * self.momentum_b[i] + (1 - self.beta1) * gradients_b[i]

                self.v_w[i] = self.beta2 * self.v_w[i] + (1 - self.beta2) * gradients_w[i]**2
                self.v_b[i] = self.beta2 * self.v_b[i] + (1 - self.beta2) * gradients_b[i]**2

                m_w_corrected = self.momentum_w[i] / (1 - self.beta1)
                m_b_corrected = self.momentum_b[i] / (1 - self.beta1)
                v_w_corrected = self.v_w[i] / (1 - self.beta2)
                v_b_corrected = self.v_b[i] / (1 - self.beta2)

                self.weights[i] -= self.learning_rate * m_w_corrected / (np.sqrt(v_w_corrected) + self.epsilon)
                self.biases[i] -= self.learning_rate * m_b_corrected / (np.sqrt(v_b_corrected) + self.epsilon)

    def calculate_loss(self, y_true, y_pred):
        return np.mean((y_pred - y_true) ** 2) + (self.l2_lambda / 2) * sum([np.sum(w ** 2) for w in self.weights])

    def calculate_accuracy(self, y_true, y_pred):
        ss_res = np.sum((y_true - y_pred) ** 2)
        ss_tot = np.sum((y_true - np.mean(y_true)) ** 2)
        r2_score = 1 - (ss_res / ss_tot)
        return r2_score

    def train(self, x_train, y_train, x_val=None, y_val=None, epochs=100):
        for epoch in range(epochs):
            y_train_pred_prev = 0  # Initial value for y(k-2)
            y_pred_train = 0  # Initial value for y(k-1)
            
            for k in range(len(x_train)):
                if k == 0:
                    x_train[k][0] = y_pred_train
                    x_train[k][1] = y_train_pred_prev
                elif k == 1:
                    x_train[k][0] = y_pred_train
                    x_train[k][1] = y_train_pred_prev
                else:
                    x_train[k][0] = y_pred_train
                    x_train[k][1] = y_train_pred_prev

                y_pred_train = self.forward(x_train[k].reshape(1, -1))
                gradients_w, gradients_b = self.backward(y_train[k], y_pred_train)
                self.update_weights(gradients_w, gradients_b)
                y_train_pred_prev = y_pred_train[0]

            y_pred_epoch_train = []
            y_train_pred_prev = 0
            y_pred_train = 0

            for k in range(len(x_train)):
                if k == 0:
                    x_train[k][0] = y_pred_train
                    x_train[k][1] = y_train_pred_prev
                elif k == 1:
                    x_train[k][0] = y_pred_train
                    x_train[k][1] = y_train_pred_prev
                else:
                    x_train[k][0] = y_pred_epoch_train[-1]
                    x_train[k][1] = y_train_pred_prev

                y_pred_epoch_train.append(self.forward(x_train[k].reshape(1, -1))[0])
                y_train_pred_prev = y_pred_epoch_train[-1]

            y_pred_epoch_train = np.array(y_pred_epoch_train)
            train_loss = self.calculate_loss(y_train, y_pred_epoch_train)
            train_acc = self.calculate_accuracy(y_train, y_pred_epoch_train)
            self.training_losses.append(train_loss)
            self.training_accuracies.append(train_acc)

            if x_val is not None and y_val is not None:
                y_pred_epoch_val = []
                y_val_pred_prev = 0
                y_pred_val = 0
                
                for k in range(len(x_val)):
                    if k == 0:
                        x_val[k][0] = y_pred_val
                        x_val[k][1] = y_val_pred_prev
                    elif k == 1:
                        x_val[k][0] = y_pred_val
                        x_val[k][1] = y_val_pred_prev
                    else:
                        x_val[k][0] = y_pred_epoch_val[-1]
                        x_val[k][1] = y_val_pred_prev

                    y_pred_epoch_val.append(self.forward(x_val[k].reshape(1, -1))[0])
                    y_val_pred_prev = y_pred_epoch_val[-1]

                y_pred_epoch_val = np.array(y_pred_epoch_val)
                val_loss = self.calculate_loss(y_val, y_pred_epoch_val)
                val_acc = self.calculate_accuracy(y_val, y_pred_epoch_val)
                self.validation_losses.append(val_loss)
                self.validation_accuracies.append(val_acc)

                if val_loss < self.best_loss:
                    self.best_loss = val_loss
                    self.best_weights = [np.copy(w) for w in self.weights]
                    self.best_biases = [np.copy(b) for b in self.biases]

                print(f"Epoch {epoch + 1}/{epochs} - "
                      f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, "
                      f"Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}")
            else:
                if train_loss < self.best_loss:
                    self.best_loss = train_loss
                    self.best_weights = [np.copy(w) for w in self.weights]
                    self.best_biases = [np.copy(b) for b in self.biases]

                print(f"Epoch {epoch + 1}/{epochs} - "
                      f"Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}")

    def predict(self, x):
        self.weights = self.best_weights
        self.biases = self.best_biases

        y_pred = []
        y_pred_prev = 0
        for k in range(len(x)):
            if k > 0:
                x[k][0] = y_pred[-1]
                x[k][1] = y_pred_prev
            current_pred = self.forward(x[k].reshape(1, -1))[0]
            y_pred.append(current_pred)
            y_pred_prev = current_pred
        return np.array(y_pred)
    
    def get_weights(self):
        return self.weights

    def get_biases(self):
        return self.biases

    def set_weights(self, weights):
        self.weights = weights

    def set_biases(self, biases):
        self.biases = biases

# %%
nnv = MLPVectoral(layers=[X.shape[-1], 12, 10,1], activations=[ 'tanh', 'tanh', 'linear'], optimizer='adam', learning_rate=0.01, l2_lambda=0.0001, weights=weights, biases=biases)

# %%
nnv.train(X_train, y_train, x_val=X_val, y_val=y_val, epochs=100)
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:146: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_train[k][0] = y_pred_train
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:147: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_train[k][1] = y_train_pred_prev
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:149: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_train[k][0] = y_pred_train
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:150: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_train[k][1] = y_train_pred_prev
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:167: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_train[k][1] = y_train_pred_prev
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:169: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_train[k][0] = y_pred_epoch_train[-1]
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:170: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_train[k][1] = y_train_pred_prev
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:192: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_val[k][1] = y_val_pred_prev
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:194: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_val[k][0] = y_pred_epoch_val[-1]
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:195: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x_val[k][1] = y_val_pred_prev
# Epoch 1/100 - Train Loss: 0.0819, Train Acc: 0.9847, Val Loss: 0.0781, Val Acc: 0.9849
# Epoch 2/100 - Train Loss: 0.0456, Train Acc: 0.9916, Val Loss: 0.0460, Val Acc: 0.9912
# Epoch 3/100 - Train Loss: 0.0366, Train Acc: 0.9933, Val Loss: 0.0351, Val Acc: 0.9933
# Epoch 4/100 - Train Loss: 0.0607, Train Acc: 0.9888, Val Loss: 0.0577, Val Acc: 0.9890
# Epoch 5/100 - Train Loss: 0.0507, Train Acc: 0.9908, Val Loss: 0.0484, Val Acc: 0.9908
# Epoch 6/100 - Train Loss: 0.0356, Train Acc: 0.9936, Val Loss: 0.0343, Val Acc: 0.9936
# Epoch 7/100 - Train Loss: 0.0435, Train Acc: 0.9922, Val Loss: 0.0417, Val Acc: 0.9922
# Epoch 8/100 - Train Loss: 0.0393, Train Acc: 0.9930, Val Loss: 0.0377, Val Acc: 0.9930
# Epoch 9/100 - Train Loss: 0.0410, Train Acc: 0.9927, Val Loss: 0.0396, Val Acc: 0.9926
# Epoch 10/100 - Train Loss: 0.0236, Train Acc: 0.9959, Val Loss: 0.0229, Val Acc: 0.9959
# Epoch 11/100 - Train Loss: 0.0272, Train Acc: 0.9953, Val Loss: 0.0259, Val Acc: 0.9953
# Epoch 12/100 - Train Loss: 0.0471, Train Acc: 0.9916, Val Loss: 0.0457, Val Acc: 0.9915
# Epoch 13/100 - Train Loss: 0.0241, Train Acc: 0.9959, Val Loss: 0.0235, Val Acc: 0.9958
# Epoch 14/100 - Train Loss: 0.0425, Train Acc: 0.9924, Val Loss: 0.0408, Val Acc: 0.9925
# Epoch 15/100 - Train Loss: 0.0381, Train Acc: 0.9933, Val Loss: 0.0369, Val Acc: 0.9932
# Epoch 16/100 - Train Loss: 0.0430, Train Acc: 0.9924, Val Loss: 0.0438, Val Acc: 0.9919
# Epoch 17/100 - Train Loss: 0.0301, Train Acc: 0.9948, Val Loss: 0.0301, Val Acc: 0.9946
# Epoch 18/100 - Train Loss: 0.0393, Train Acc: 0.9931, Val Loss: 0.0377, Val Acc: 0.9931
# Epoch 19/100 - Train Loss: 0.0390, Train Acc: 0.9931, Val Loss: 0.0390, Val Acc: 0.9928
# Epoch 20/100 - Train Loss: 0.0378, Train Acc: 0.9933, Val Loss: 0.0366, Val Acc: 0.9933
# Epoch 21/100 - Train Loss: 0.0269, Train Acc: 0.9954, Val Loss: 0.0259, Val Acc: 0.9954
# Epoch 22/100 - Train Loss: 0.0374, Train Acc: 0.9934, Val Loss: 0.0361, Val Acc: 0.9934
# Epoch 23/100 - Train Loss: 0.0241, Train Acc: 0.9959, Val Loss: 0.0235, Val Acc: 0.9959
# Epoch 24/100 - Train Loss: 0.0681, Train Acc: 0.9877, Val Loss: 0.0670, Val Acc: 0.9874
# Epoch 25/100 - Train Loss: 0.0622, Train Acc: 0.9888, Val Loss: 0.0605, Val Acc: 0.9886
# Epoch 26/100 - Train Loss: 0.0344, Train Acc: 0.9940, Val Loss: 0.0337, Val Acc: 0.9939
# Epoch 27/100 - Train Loss: 0.0598, Train Acc: 0.9892, Val Loss: 0.0584, Val Acc: 0.9890
# Epoch 28/100 - Train Loss: 0.0324, Train Acc: 0.9944, Val Loss: 0.0301, Val Acc: 0.9946
# Epoch 29/100 - Train Loss: 0.0344, Train Acc: 0.9940, Val Loss: 0.0317, Val Acc: 0.9943
# Epoch 30/100 - Train Loss: 0.0268, Train Acc: 0.9954, Val Loss: 0.0244, Val Acc: 0.9957
# Epoch 31/100 - Train Loss: 0.0253, Train Acc: 0.9957, Val Loss: 0.0235, Val Acc: 0.9958
# Epoch 32/100 - Train Loss: 0.0285, Train Acc: 0.9951, Val Loss: 0.0270, Val Acc: 0.9952
# Epoch 33/100 - Train Loss: 0.0229, Train Acc: 0.9961, Val Loss: 0.0225, Val Acc: 0.9960
# Epoch 34/100 - Train Loss: 0.0500, Train Acc: 0.9910, Val Loss: 0.0472, Val Acc: 0.9912
# Epoch 35/100 - Train Loss: 0.0151, Train Acc: 0.9976, Val Loss: 0.0148, Val Acc: 0.9975
# Epoch 36/100 - Train Loss: 0.0210, Train Acc: 0.9965, Val Loss: 0.0201, Val Acc: 0.9965
# Epoch 37/100 - Train Loss: 0.0319, Train Acc: 0.9944, Val Loss: 0.0297, Val Acc: 0.9946
# Epoch 38/100 - Train Loss: 0.0283, Train Acc: 0.9951, Val Loss: 0.0265, Val Acc: 0.9952
# Epoch 39/100 - Train Loss: 0.0269, Train Acc: 0.9954, Val Loss: 0.0251, Val Acc: 0.9955
# Epoch 40/100 - Train Loss: 0.0477, Train Acc: 0.9915, Val Loss: 0.0453, Val Acc: 0.9916
# Epoch 41/100 - Train Loss: 0.0350, Train Acc: 0.9938, Val Loss: 0.0327, Val Acc: 0.9940
# Epoch 42/100 - Train Loss: 0.0384, Train Acc: 0.9932, Val Loss: 0.0363, Val Acc: 0.9933
# Epoch 43/100 - Train Loss: 0.0373, Train Acc: 0.9934, Val Loss: 0.0358, Val Acc: 0.9934
# Epoch 44/100 - Train Loss: 0.0898, Train Acc: 0.9836, Val Loss: 0.0882, Val Acc: 0.9832
# Epoch 45/100 - Train Loss: 0.0490, Train Acc: 0.9912, Val Loss: 0.0471, Val Acc: 0.9912
# Epoch 46/100 - Train Loss: 0.0334, Train Acc: 0.9942, Val Loss: 0.0318, Val Acc: 0.9942
# Epoch 47/100 - Train Loss: 0.0339, Train Acc: 0.9941, Val Loss: 0.0328, Val Acc: 0.9940
# Epoch 48/100 - Train Loss: 0.0247, Train Acc: 0.9958, Val Loss: 0.0237, Val Acc: 0.9958
# Epoch 49/100 - Train Loss: 0.0296, Train Acc: 0.9949, Val Loss: 0.0287, Val Acc: 0.9948
# Epoch 50/100 - Train Loss: 0.0397, Train Acc: 0.9930, Val Loss: 0.0384, Val Acc: 0.9929
# Epoch 51/100 - Train Loss: 0.0317, Train Acc: 0.9945, Val Loss: 0.0302, Val Acc: 0.9945
# Epoch 52/100 - Train Loss: 0.0341, Train Acc: 0.9940, Val Loss: 0.0328, Val Acc: 0.9940
# Epoch 53/100 - Train Loss: 0.0302, Train Acc: 0.9947, Val Loss: 0.0294, Val Acc: 0.9947
# Epoch 54/100 - Train Loss: 0.0278, Train Acc: 0.9952, Val Loss: 0.0270, Val Acc: 0.9952
# Epoch 55/100 - Train Loss: 0.0222, Train Acc: 0.9963, Val Loss: 0.0211, Val Acc: 0.9963
# Epoch 56/100 - Train Loss: 0.0215, Train Acc: 0.9964, Val Loss: 0.0212, Val Acc: 0.9963
# Epoch 57/100 - Train Loss: 0.0215, Train Acc: 0.9964, Val Loss: 0.0207, Val Acc: 0.9964
# Epoch 58/100 - Train Loss: 0.0119, Train Acc: 0.9982, Val Loss: 0.0114, Val Acc: 0.9982
# Epoch 59/100 - Train Loss: 0.0188, Train Acc: 0.9969, Val Loss: 0.0190, Val Acc: 0.9967
# Epoch 60/100 - Train Loss: 0.0235, Train Acc: 0.9960, Val Loss: 0.0226, Val Acc: 0.9960
# Epoch 61/100 - Train Loss: 0.0240, Train Acc: 0.9959, Val Loss: 0.0232, Val Acc: 0.9959
# Epoch 62/100 - Train Loss: 0.0217, Train Acc: 0.9963, Val Loss: 0.0210, Val Acc: 0.9963
# Epoch 63/100 - Train Loss: 0.0233, Train Acc: 0.9960, Val Loss: 0.0227, Val Acc: 0.9960
# Epoch 64/100 - Train Loss: 0.0330, Train Acc: 0.9942, Val Loss: 0.0326, Val Acc: 0.9941
# Epoch 65/100 - Train Loss: 0.0210, Train Acc: 0.9965, Val Loss: 0.0206, Val Acc: 0.9964
# Epoch 66/100 - Train Loss: 0.0308, Train Acc: 0.9946, Val Loss: 0.0305, Val Acc: 0.9945
# Epoch 67/100 - Train Loss: 0.0152, Train Acc: 0.9976, Val Loss: 0.0150, Val Acc: 0.9975
# Epoch 68/100 - Train Loss: 0.0411, Train Acc: 0.9927, Val Loss: 0.0394, Val Acc: 0.9927
# Epoch 69/100 - Train Loss: 0.0241, Train Acc: 0.9959, Val Loss: 0.0240, Val Acc: 0.9957
# Epoch 70/100 - Train Loss: 0.0152, Train Acc: 0.9976, Val Loss: 0.0148, Val Acc: 0.9975
# Epoch 71/100 - Train Loss: 0.0137, Train Acc: 0.9978, Val Loss: 0.0135, Val Acc: 0.9978
# Epoch 72/100 - Train Loss: 0.0227, Train Acc: 0.9962, Val Loss: 0.0226, Val Acc: 0.9960
# Epoch 73/100 - Train Loss: 0.0241, Train Acc: 0.9959, Val Loss: 0.0235, Val Acc: 0.9958
# Epoch 74/100 - Train Loss: 0.0538, Train Acc: 0.9903, Val Loss: 0.0518, Val Acc: 0.9903
# Epoch 75/100 - Train Loss: 0.0243, Train Acc: 0.9959, Val Loss: 0.0237, Val Acc: 0.9958
# Epoch 76/100 - Train Loss: 0.0463, Train Acc: 0.9917, Val Loss: 0.0452, Val Acc: 0.9916
# Epoch 77/100 - Train Loss: 0.0226, Train Acc: 0.9962, Val Loss: 0.0217, Val Acc: 0.9962
# Epoch 78/100 - Train Loss: 0.0201, Train Acc: 0.9967, Val Loss: 0.0198, Val Acc: 0.9966
# Epoch 79/100 - Train Loss: 0.0137, Train Acc: 0.9978, Val Loss: 0.0135, Val Acc: 0.9978
# Epoch 80/100 - Train Loss: 0.0243, Train Acc: 0.9959, Val Loss: 0.0238, Val Acc: 0.9958
# Epoch 81/100 - Train Loss: 0.0153, Train Acc: 0.9976, Val Loss: 0.0149, Val Acc: 0.9975
# Epoch 82/100 - Train Loss: 0.0157, Train Acc: 0.9975, Val Loss: 0.0152, Val Acc: 0.9975
# Epoch 83/100 - Train Loss: 0.0169, Train Acc: 0.9973, Val Loss: 0.0171, Val Acc: 0.9971
# Epoch 84/100 - Train Loss: 0.0123, Train Acc: 0.9981, Val Loss: 0.0121, Val Acc: 0.9981
# Epoch 85/100 - Train Loss: 0.0202, Train Acc: 0.9966, Val Loss: 0.0196, Val Acc: 0.9966
# Epoch 86/100 - Train Loss: 0.0239, Train Acc: 0.9959, Val Loss: 0.0231, Val Acc: 0.9959
# Epoch 87/100 - Train Loss: 0.0311, Train Acc: 0.9946, Val Loss: 0.0303, Val Acc: 0.9945
# Epoch 88/100 - Train Loss: 0.0206, Train Acc: 0.9966, Val Loss: 0.0202, Val Acc: 0.9965
# Epoch 89/100 - Train Loss: 0.0223, Train Acc: 0.9962, Val Loss: 0.0219, Val Acc: 0.9962
# Epoch 90/100 - Train Loss: 0.0334, Train Acc: 0.9942, Val Loss: 0.0320, Val Acc: 0.9942
# Epoch 91/100 - Train Loss: 0.0229, Train Acc: 0.9961, Val Loss: 0.0225, Val Acc: 0.9960
# Epoch 92/100 - Train Loss: 0.0378, Train Acc: 0.9933, Val Loss: 0.0369, Val Acc: 0.9932
# Epoch 93/100 - Train Loss: 0.0321, Train Acc: 0.9944, Val Loss: 0.0312, Val Acc: 0.9943
# Epoch 94/100 - Train Loss: 0.0241, Train Acc: 0.9959, Val Loss: 0.0240, Val Acc: 0.9958
# Epoch 95/100 - Train Loss: 0.0222, Train Acc: 0.9963, Val Loss: 0.0216, Val Acc: 0.9962
# Epoch 96/100 - Train Loss: 0.0254, Train Acc: 0.9957, Val Loss: 0.0245, Val Acc: 0.9957
# Epoch 97/100 - Train Loss: 0.0257, Train Acc: 0.9956, Val Loss: 0.0245, Val Acc: 0.9957
# Epoch 98/100 - Train Loss: 0.0382, Train Acc: 0.9933, Val Loss: 0.0372, Val Acc: 0.9932
# Epoch 99/100 - Train Loss: 0.0238, Train Acc: 0.9960, Val Loss: 0.0232, Val Acc: 0.9959
# Epoch 100/100 - Train Loss: 0.0172, Train Acc: 0.9972, Val Loss: 0.0166, Val Acc: 0.9972

# %%
training_losses = nnv.training_losses
validation_losses = nnv.validation_losses
training_accuracies = nnv.training_accuracies
validation_accuracies = nnv.validation_accuracies

# Create a figure with 1 row and 2 columns for loss and accuracy plots
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Create a range of epochs for the x-axis
epochs = range(1, len(training_losses) + 1)

# Plot Loss with Logarithmic X-Axis
sns.lineplot(x=epochs, y=training_losses, ax=ax[0], label='Training Loss', color='blue')
sns.lineplot(x=epochs, y=validation_losses, ax=ax[0], label='Validation Loss', color='orange')
# ax[0].set_xscale('log')  # Set x-axis to logarithmic scale
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss')
ax[0].set_title('Training and Validation Loss')
ax[0].legend()

# Plot Accuracy with Logarithmic X-Axis
sns.lineplot(x=epochs, y=training_accuracies, ax=ax[1], label='Training Accuracy', color='blue')
sns.lineplot(x=epochs, y=validation_accuracies, ax=ax[1], label='Validation Accuracy', color='orange')
# ax[1].set_xscale('log')  # Set x-axis to logarithmic scale
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('R² Score')
ax[1].set_title('Training and Validation Accuracy (R² Score)')
ax[1].legend()

# Adjust layout and show the plots
plt.tight_layout()
plt.show()

# %%
y_train_pred_norm = nnv.predict(X_train_norm)
y_val_pred_norm = nnv.predict(X_val_norm)
y_train_pred = scaler.inverse_transform(y_train_pred_norm)
y_val_pred = scaler.inverse_transform(y_val_pred_norm)

# Assuming y_train, y_pred_train, y_val, and y_pred_val are already defined
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Generate time indices for training and validation
train_indices = range(len(y_train))
val_indices = range(len(y_val))

# Plot y_pred_train and y_train over time (k) with reduced alpha for predicted line
sns.lineplot(x=train_indices, y=y_train.flatten(), ax=ax[0], color='blue', label='Actual Train', linewidth=1)
sns.lineplot(x=train_indices, y=y_pred_train.flatten(), ax=ax[0], color='orange', label='Predicted Train', alpha=0.5, linewidth=1)
ax[0].set_xlabel('Time Index (k)')
ax[0].set_ylabel('Values')
ax[0].set_title('Training Data: Actual vs Predicted Over Time')
ax[0].legend()

# Plot y_pred_val and y_val over time (k) with reduced alpha for predicted line
sns.lineplot(x=val_indices, y=y_val.flatten(), ax=ax[1], color='blue', label='Actual Val', linewidth=1)
sns.lineplot(x=val_indices, y=y_pred_val.flatten(), ax=ax[1], color='orange', label='Predicted Val', alpha=0.5, linewidth=1)
ax[1].set_xlabel('Time Index (k)')
ax[1].set_ylabel('Values')
ax[1].set_title('Validation Data: Actual vs Predicted Over Time')
ax[1].legend()

# Show the updated plots
plt.tight_layout()
plt.show()
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:231: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[k][0] = y_pred[-1]
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:232: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[k][1] = y_pred_prev

# %%
t_test = np.linspace(0, k_max, k_max)  # Time variable (consistent across inputs)

# Generate sinusoidal input for u_test_sin(k)
frequency = 5    # Frequency of the sine wave
amplitude = 10   # Amplitude of the sine wave
phase = 0        # Phase shift of the sine wave
u_test_sin = amplitude * np.sin(2 * np.pi * frequency * t_test + phase)

# Initialize y_test_sin(k) array and calculate values based on the given formula
y_test_sin = np.zeros(k_max)
for k in range(1, k_max):
    y_test_sin[k] = 1 / (1 + (y_test_sin[k-1])**2) + 0.25 * u_test_sin[k] - 0.3 * u_test_sin[k-1]

# Shift arrays for y_test_sin(k-1), y_test_sin(k-2), u_test_sin(k-1), u_test_sin(k-2)
y_k_1_test_sin = np.zeros(k_max)
y_k_2_test_sin = np.zeros(k_max)
u_k_1_test_sin = np.zeros(k_max)
u_k_2_test_sin = np.zeros(k_max)

y_k_1_test_sin[1:] = y_test_sin[:-1]
y_k_2_test_sin[2:] = y_test_sin[:-2]
u_k_1_test_sin[1:] = u_test_sin[:-1]
u_k_2_test_sin[2:] = u_test_sin[:-2]

# Initialize MinMaxScaler to scale between -1 and 1
scaler_y = MinMaxScaler(feature_range=(-1, 1))
scaler_u = MinMaxScaler(feature_range=(-1, 1))

# Fit the scalers on training data (assuming y and u are defined)
scaler_y.fit(y.reshape(-1, 1))  # Fit on y
scaler_u.fit(u.reshape(-1, 1))  # Fit on u

# Normalize the testing data using the fitted scalers
y_test_sin_norm = scaler_y.transform(y_test_sin.reshape(-1, 1)).flatten()
y_k_1_test_sin_norm = scaler_y.transform(y_k_1_test_sin.reshape(-1, 1)).flatten()
y_k_2_test_sin_norm = scaler_y.transform(y_k_2_test_sin.reshape(-1, 1)).flatten()

u_test_sin_norm = scaler_u.transform(u_test_sin.reshape(-1, 1)).flatten()
u_k_1_test_sin_norm = scaler_u.transform(u_k_1_test_sin.reshape(-1, 1)).flatten()
u_k_2_test_sin_norm = scaler_u.transform(u_k_2_test_sin.reshape(-1, 1)).flatten()

# Prepare input matrices for the models
X_test_sin_norm = np.array([y_k_1_test_sin_norm, y_k_2_test_sin_norm, u_test_sin_norm, u_k_1_test_sin_norm, u_k_2_test_sin_norm]).T
X_test_sin = np.array([y_k_1_test_sin, y_k_2_test_sin, u_test_sin, u_k_1_test_sin, u_k_2_test_sin]).T

# Make predictions using the models
y_pred_test_sin_t2 = nnv.predict(X_test_sin).flatten()  # Predictions from model nnv
y_pred_test_sin_t1 = nn.predict(X_test_sin).flatten()   # Predictions from model nn
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:231: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[k][0] = y_pred[-1]
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:232: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[k][1] = y_pred_prev

# %%
# Create a figure with 1 row and 2 columns
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Plot the input signal (u_test_sin) in the first subplot
sns.lineplot(x=range(len(u_test_sin)), y=u_test_sin, ax=ax[0], color='blue', label='Input Signal (u)')
ax[0].set_xlabel('Time Index (k)')
ax[0].set_ylabel('Input Value')
ax[0].set_title('Input Signal (Sinusoidal)')
ax[0].legend()

# Plot actual vs. predicted output (y_test_sin vs. y_pred_test_sin_t1) in the second subplot
sns.lineplot(x=range(len(y_test_sin)), y=y_test_sin, ax=ax[1], color='green', label='Actual Output (y)')
sns.lineplot(x=range(len(y_test_sin)), y=y_pred_test_sin_t1, ax=ax[1], color='red', linestyle='--', label='Predicted Output')
ax[1].set_xlabel('Time Index (k)')
ax[1].set_ylabel('Output Value')
ax[1].set_title('Actual vs. Predicted Output (Stage 1)')
ax[1].legend()

# Adjust the layout and show the plots
plt.tight_layout()
plt.show()

# %%
# Create a figure with 1 row and 2 columns
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Plot the input signal (u_test_sin) in the first subplot
sns.lineplot(x=range(len(u_test_sin)), y=u_test_sin, ax=ax[0], color='blue', label='Input Signal (u)')
ax[0].set_xlabel('Time Index (k)')
ax[0].set_ylabel('Input Value')
ax[0].set_title('Input Signal (Sinusoidal)')
ax[0].legend()

# Plot actual vs. predicted output (y_test_sin vs. y_pred_test_sin_t1) in the second subplot
sns.lineplot(x=range(len(y_test_sin)), y=y_test_sin, ax=ax[1], color='green', label='Actual Output (y)')
sns.lineplot(x=range(len(y_test_sin)), y=y_pred_test_sin_t2, ax=ax[1], color='red', linestyle='--', label='Predicted Output')
ax[1].set_xlabel('Time Index (k)')
ax[1].set_ylabel('Output Value')
ax[1].set_title('Actual vs. Predicted Output (Stage 2)')
ax[1].legend()

# Adjust the layout and show the plots
plt.tight_layout()
plt.show()

# %%
# Generate square wave input for u_test_square(k)
frequency = 2    # Frequency of the square wave
amplitude = 10   # Amplitude of the square wave
u_test_square = amplitude * signal.square(2 * np.pi * frequency * t_test)

# Initialize y_test_square(k) array and calculate values based on the given formula
y_test_square = np.zeros(k_max)
for k in range(1, k_max):
    y_test_square[k] = 1 / (1 + (y_test_square[k-1])**2) + 0.25 * u_test_square[k] - 0.3 * u_test_square[k-1]

# Shift arrays for y_test_square(k-1), y_test_square(k-2), u_test_square(k-1), u_test_square(k-2)
y_k_1_test_square = np.zeros(k_max)
y_k_2_test_square = np.zeros(k_max)
u_k_1_test_square = np.zeros(k_max)
u_k_2_test_square = np.zeros(k_max)

y_k_1_test_square[1:] = y_test_square[:-1]
y_k_2_test_square[2:] = y_test_square[:-2]
u_k_1_test_square[1:] = u_test_square[:-1]
u_k_2_test_square[2:] = u_test_square[:-2]

# Initialize MinMaxScaler to scale between -1 and 1
scaler_y = MinMaxScaler(feature_range=(-1, 1))
scaler_u = MinMaxScaler(feature_range=(-1, 1))

# Fit the scalers on training data (assuming y and u are defined)
scaler_y.fit(y.reshape(-1, 1))  # Fit on y
scaler_u.fit(u.reshape(-1, 1))  # Fit on u

# Normalize the testing data using the fitted scalers
y_test_square_norm = scaler_y.transform(y_test_square.reshape(-1, 1)).flatten()
y_k_1_test_square_norm = scaler_y.transform(y_k_1_test_square.reshape(-1, 1)).flatten()
y_k_2_test_square_norm = scaler_y.transform(y_k_2_test_square.reshape(-1, 1)).flatten()

u_test_square_norm = scaler_u.transform(u_test_square.reshape(-1, 1)).flatten()
u_k_1_test_square_norm = scaler_u.transform(u_k_1_test_square.reshape(-1, 1)).flatten()
u_k_2_test_square_norm = scaler_u.transform(u_k_2_test_square.reshape(-1, 1)).flatten()

# Prepare input matrices for the models
X_test_square_norm = np.array([y_k_1_test_square_norm, y_k_2_test_square_norm, u_test_square_norm, u_k_1_test_square_norm, u_k_2_test_square_norm]).T
X_test_square = np.array([y_k_1_test_square, y_k_2_test_square, u_test_square, u_k_1_test_square, u_k_2_test_square]).T

# Make predictions using the models
y_pred_test_square_t2 = nnv.predict(X_test_square).flatten()  # Predictions from model nnv
y_pred_test_square_t1 = nn.predict(X_test_square).flatten()   # Predictions from model nn
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:231: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[k][0] = y_pred[-1]
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:232: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[k][1] = y_pred_prev

# %%
# Create a figure with 1 row and 2 columns to visualize square wave input and model output
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Plot the input signal (u_test_square) in the first subplot
sns.lineplot(x=range(len(u_test_square)), y=u_test_square, ax=ax[0], color='blue', label='Input Signal (Square Wave)')
ax[0].set_xlabel('Time Index (k)')
ax[0].set_ylabel('Input Value')
ax[0].set_title('Input Signal (Square Wave)')
ax[0].legend()

# Plot actual vs. predicted output (y_test_square vs. y_pred_test_square_t1) in the second subplot
sns.lineplot(x=range(len(y_test_square)), y=y_test_square, ax=ax[1], color='green', label='Actual Output (y)')
sns.lineplot(x=range(len(y_test_square)), y=y_pred_test_square_t1, ax=ax[1], color='red', linestyle='--', label='Predicted Output')
ax[1].set_xlabel('Time Index (k)')
ax[1].set_ylabel('Output Value')
ax[1].set_title('Actual vs. Predicted Output (Square Wave)')
ax[1].legend()

# Adjust the layout and show the plots
plt.tight_layout()
plt.show()

# %%
# Create a figure with 1 row and 2 columns to visualize square wave input and model output
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Plot the input signal (u_test_square) in the first subplot
sns.lineplot(x=range(len(u_test_square)), y=u_test_square, ax=ax[0], color='blue', label='Input Signal (Square Wave)')
ax[0].set_xlabel('Time Index (k)')
ax[0].set_ylabel('Input Value')
ax[0].set_title('Input Signal (Square Wave)')
ax[0].legend()

# Plot actual vs. predicted output (y_test_square vs. y_pred_test_square_t1) in the second subplot
sns.lineplot(x=range(len(y_test_square)), y=y_test_square, ax=ax[1], color='green', label='Actual Output (y)')
sns.lineplot(x=range(len(y_test_square)), y=y_pred_test_square_t2, ax=ax[1], color='red', linestyle='--', label='Predicted Output')
ax[1].set_xlabel('Time Index (k)')
ax[1].set_ylabel('Output Value')
ax[1].set_title('Actual vs. Predicted Output (Square Wave)')
ax[1].legend()

# Adjust the layout and show the plots
plt.tight_layout()
plt.show()

# %%
# Generate triangle wave input for u_test_triangle(k)
frequency = 5    # Frequency of the triangle wave
amplitude = 10   # Amplitude of the triangle wave
u_test_triangle = amplitude * signal.sawtooth(2 * np.pi * frequency * t_test, 0.5)  # 0.5 duty cycle for a triangle wave

# Initialize y_test_triangle(k) array and calculate values based on the given formula
y_test_triangle = np.zeros(k_max)
for k in range(1, k_max):
    y_test_triangle[k] = 1 / (1 + (y_test_triangle[k-1])**2) + 0.25 * u_test_triangle[k] - 0.3 * u_test_triangle[k-1]

# Shift arrays for y_test_triangle(k-1), y_test_triangle(k-2), u_test_triangle(k-1), u_test_triangle(k-2)
y_k_1_test_triangle = np.zeros(k_max)
y_k_2_test_triangle = np.zeros(k_max)
u_k_1_test_triangle = np.zeros(k_max)
u_k_2_test_triangle = np.zeros(k_max)

y_k_1_test_triangle[1:] = y_test_triangle[:-1]
y_k_2_test_triangle[2:] = y_test_triangle[:-2]
u_k_1_test_triangle[1:] = u_test_triangle[:-1]
u_k_2_test_triangle[2:] = u_test_triangle[:-2]

# Initialize MinMaxScaler to scale between -1 and 1
scaler_y = MinMaxScaler(feature_range=(-1, 1))
scaler_u = MinMaxScaler(feature_range=(-1, 1))

# Fit the scalers on training data (assuming y and u are defined)
scaler_y.fit(y.reshape(-1, 1))  # Fit on y
scaler_u.fit(u.reshape(-1, 1))  # Fit on u

# Normalize the testing data using the fitted scalers
y_test_triangle_norm = scaler_y.transform(y_test_triangle.reshape(-1, 1)).flatten()
y_k_1_test_triangle_norm = scaler_y.transform(y_k_1_test_triangle.reshape(-1, 1)).flatten()
y_k_2_test_triangle_norm = scaler_y.transform(y_k_2_test_triangle.reshape(-1, 1)).flatten()

u_test_triangle_norm = scaler_u.transform(u_test_triangle.reshape(-1, 1)).flatten()
u_k_1_test_triangle_norm = scaler_u.transform(u_k_1_test_triangle.reshape(-1, 1)).flatten()
u_k_2_test_triangle_norm = scaler_u.transform(u_k_2_test_triangle.reshape(-1, 1)).flatten()

# Prepare input matrices for the models
X_test_triangle_norm = np.array([y_k_1_test_triangle_norm, y_k_2_test_triangle_norm, u_test_triangle_norm, u_k_1_test_triangle_norm, u_k_2_test_triangle_norm]).T
X_test_triangle = np.array([y_k_1_test_triangle, y_k_2_test_triangle, u_test_triangle, u_k_1_test_triangle, u_k_2_test_triangle]).T

# Make predictions using the models
y_pred_test_triangle_t2 = nnv.predict(X_test_triangle).flatten()  # Predictions from model nnv
y_pred_test_triangle_t1 = nn.predict(X_test_triangle).flatten()   # Predictions from model nn
# Out:
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:231: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[k][0] = y_pred[-1]
# C:\Users\SteinSteffi1\AppData\Local\Temp\ipykernel_1512\1622018699.py:232: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   x[k][1] = y_pred_prev

# %%
# Create a figure with 1 row and 2 columns to visualize triangle wave input and model output
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Plot the input signal (u_test_triangle) in the first subplot
sns.lineplot(x=range(len(u_test_triangle)), y=u_test_triangle, ax=ax[0], color='blue', label='Input Signal (Triangle Wave)')
ax[0].set_xlabel('Time Index (k)')
ax[0].set_ylabel('Input Value')
ax[0].set_title('Input Signal (Triangle Wave)')
ax[0].legend()

# Plot actual vs. predicted output (y_test_triangle vs. y_pred_test_triangle_t1) in the second subplot
sns.lineplot(x=range(len(y_test_triangle)), y=y_test_triangle, ax=ax[1], color='green', label='Actual Output (y)')
sns.lineplot(x=range(len(y_test_triangle)), y=y_pred_test_triangle_t1, ax=ax[1], color='red', linestyle='--', label='Predicted Output')
ax[1].set_xlabel('Time Index (k)')
ax[1].set_ylabel('Output Value')
ax[1].set_title('Actual vs. Predicted Output (Triangle Wave)')
ax[1].legend()

# Adjust the layout and show the plots
plt.tight_layout()
plt.show()

# %%
# Create a figure with 1 row and 2 columns to visualize triangle wave input and model output
fig, ax = plt.subplots(1, 2, figsize=(14, 6))

# Plot the input signal (u_test_triangle) in the first subplot
sns.lineplot(x=range(len(u_test_triangle)), y=u_test_triangle, ax=ax[0], color='blue', label='Input Signal (Triangle Wave)')
ax[0].set_xlabel('Time Index (k)')
ax[0].set_ylabel('Input Value')
ax[0].set_title('Input Signal (Triangle Wave)')
ax[0].legend()

# Plot actual vs. predicted output (y_test_triangle vs. y_pred_test_triangle_t1) in the second subplot
sns.lineplot(x=range(len(y_test_triangle)), y=y_test_triangle, ax=ax[1], color='green', label='Actual Output (y)')
sns.lineplot(x=range(len(y_test_triangle)), y=y_pred_test_triangle_t2, ax=ax[1], color='red', linestyle='--', label='Predicted Output')
ax[1].set_xlabel('Time Index (k)')
ax[1].set_ylabel('Output Value')
ax[1].set_title('Actual vs. Predicted Output (Triangle Wave)')
ax[1].legend()

# Adjust the layout and show the plots
plt.tight_layout()
plt.show()

# %%
# data for inverse model

# training inverse model
nn_inverse = MLPVectoral(layers=[X.shape[-1], 7, 7, 7, 1], activations=['tanh', 'tanh', 'tanh', 'linear'], optimizer='adam', learning_rate=0.01, l2_lambda=0.0001)
